# %% [markdown]
# # 🧭 1. Entendimento do Negócio: Insights do Tráfego Aéreo para a AeroVision

# %% [markdown]
# ## 1.1 Contexto
#
# AeroVision é uma companhia aérea americana de médio porte que opera rotas domésticas e internacionais.
#
# Com uma frota diversificada e presença em aeroportos de grande movimentação, a empresa enfrenta desafios crescentes relacionados à eficiência operacional, alocação de aeronaves e aumento dos custos com combustível, manutenção e logística.
#
# Em um mercado altamente competitivo e com margens cada vez mais apertadas, a AeroVision busca utilizar dados históricos de tráfego aéreo para apoiar decisões estratégicas que aumentem a rentabilidade, reduzam custos operacionais e mitiguem riscos.
#
# Este projeto utiliza dados públicos sobre pousos de aeronaves no Aeroporto Internacional de San Francisco (SFO) como proxy analítica, com o objetivo de identificar padrões operacionais, indicadores de desempenho e oportunidades que possam ser adaptadas à realidade da AeroVision.
#
# **🔍 Premissa**
#
# “Embora os dados analisados sejam específicos do Aeroporto Internacional de San Francisco (SFO), eles são utilizados aqui como uma referência analítica.
#
# Essa abordagem é útil em estudos de benchmarking e permite extrair insights estratégicos que podem ser aplicados à operação da AeroVision em outros hubs de grande porte.”

# %% [markdown]
# ## 1.2 Objetivos do Projeto
#
# Com base no estudo de dados de pousos de aeronaves no Aeroporto Internacional de San Francisco (SFO), o projeto visa levantar insights de alto impacto financeiro que possam ser adaptados à realidade da AeroVision, com foco em eficiência operacional, gestão de risco, redução de custos e aumento de receita.
#
#
# As seguintes perguntas de negócio foram formuladas:
#
# **Quais características das aeronaves mais influenciam a operação em rotas internacionais?**
#
# **Quais fatores aumentam a probabilidade de uma aeronave operar frequentemente no aeroporto?**
#
# **Quais fabricantes estão mais associados a alto peso total pousado?**
#
# **Qual a chance de uma combinação companhia + tipo de aeronave ter baixa performance (poucos pousos)?**
#
# **Quais variáveis explicam melhor o uso de aeronaves de corpo largo?**

# %% [markdown]
# ## 1.3 Benefícios Esperados
#
# Redução de custos operacionais via melhor distribuição da frota.
#
# Melhora da previsão de demanda e planejamento de recursos.
#
# Apoio na tomada de decisão para desenvolvimento de componentes aeronáuticos mais aderentes ao mercado internacional.
#
# Direcionamento estratégico de parcerias com fabricantes.

# %% [markdown]
# ## 1.4 Análise SWOT
#
# **Forças (Strengths)**
#
#
#
#
#
# Alta movimentação no SFO: O Aeroporto Internacional de San Francisco é um dos principais hubs dos EUA, com grande volume de tráfego aéreo, permitindo à AeroVision explorar rotas de alta demanda.
#
#
#
# Frota diversificada: A AeroVision possui uma frota variada, capaz de atender tanto rotas domésticas quanto internacionais, oferecendo flexibilidade operacional.
#
#
#
# Acesso a dados históricos: A análise de dados de pousos no SFO fornece insights valiosos para otimização de rotas, alocação de aeronaves e previsão de demanda.
#
#
#
# Localização estratégica: A proximidade do SFO com mercados asiáticos e da costa oeste dos EUA favorece a operação de rotas internacionais rentáveis.
#
# **Fraquezas (Weaknesses)**
#
#
#
#
#
# Custos operacionais elevados: Altos custos com combustível, manutenção e taxas aeroportuárias no SFO pressionam as margens da AeroVision.
#
#
#
# Competitividade acirrada: O mercado no SFO é dominado por grandes companhias aéreas, dificultando a conquista de market share.
#
#
#
# Dependência de eficiência operacional: Pequenos atrasos ou problemas logísticos no SFO, um aeroporto congestionado, podem gerar perdas significativas.
#
#
#
# Limitações de frota: Algumas aeronaves podem não ser otimizadas para rotas internacionais de longo curso, aumentando custos ou reduzindo competitividade.
#
# **Oportunidades (Opportunities)**
#
#
#
#
#
# Otimização com base em dados: A análise de dados de tráfego aéreo pode identificar padrões de uso de aeronaves, permitindo melhor alocação de frota e redução de custos.
#
#
#
# Parcerias com fabricantes: Insights sobre fabricantes associados a alto peso total pousado ou aeronaves de corpo largo podem guiar negociações estratégicas para aquisição de novos modelos.
#
#
#
# Crescimento do mercado internacional: A demanda por rotas transpacíficas está em alta, e o SFO é uma porta de entrada ideal para esses mercados.
#
#
#
# Sustentabilidade: Investir em aeronaves mais eficientes em termos de combustível, baseando-se nos dados de performance, pode atrair clientes preocupados com impacto ambiental.
#
# **Ameaças (Threats)**
#
#
#
#
#
# Volatilidade dos custos de combustível: Flutuações nos preços do combustível impactam diretamente a rentabilidade das operações.
#
#
#
# Regulamentações ambientais: Novas normas de emissões podem exigir investimentos em modernização de frota ou adaptações operacionais.
#
#
#
# Congestionamento no SFO: O alto tráfego aéreo pode levar a atrasos, aumentando custos e afetando a experiência do cliente.
#
#
#
# Concorrência de low-cost carriers: Companhias de baixo custo podem pressionar os preços das passagens, reduzindo as margens da AeroVision.

# %% [markdown]
# ## 1.5 Objetivos SMART
#
# **1.Reduzir Custos Operacionais em 10% em 12 Meses**
#
#
#
#
#
# *Específico (Specific)*: Otimizar a alocação de aeronaves com base em dados de pousos no SFO, priorizando modelos com maior eficiência em rotas internacionais.
#
#
#
# *Mensurável (Measurable)*: Reduzir os custos operacionais (combustível, manutenção e taxas) em 10%, medidos por relatórios financeiros trimestrais.
#
#
#
# *Atingível (Achievable)*: Utilizar insights de dados para redistribuir a frota, focando em aeronaves de alto desempenho e reduzindo voos com baixa ocupação.
#
#
#
# *Relevante (Relevant)*: A redução de custos é crítica para aumentar a competitividade em um mercado de margens apertadas.
#
#
#
# *Temporal (Time-bound)*: Alcançar a meta em 12 meses, com revisões trimestrais para ajustes.
#
# **2. Aumentar a Frequência de Operações de Aeronaves de Corpo Largo em 15% em 18 Meses**
#
#
#
#
#
# *Específico (Specific)*: Identificar variáveis que explicam o uso de aeronaves de corpo largo no SFO e aumentar sua utilização em rotas internacionais.
#
#
#
# *Mensurável (Measurable)*: Aumentar em 15% o número de pousos de aeronaves de corpo largo, monitorado por relatórios de tráfego aéreo.
#
#
#
# *Atingível (Achievable)*: Com base em dados históricos, ajustar o planejamento de rotas para priorizar aeronaves de maior capacidade em voos de alta demanda.
#
#
#
# *Relevante (Relevant)*: Aeronaves de corpo largo são mais rentáveis em rotas internacionais, alinhando-se ao crescimento do mercado transpacífico.
#
#
#
# *Temporal (Time-bound)*: Implementar em 18 meses, com metas intermediárias a cada 6 meses.
#
# **3. Estabelecer Parcerias Estratégicas com Fabricantes em 24 Meses**
#
#
#
#
#
# *Específico (Specific)*: Identificar fabricantes associados a aeronaves de alto peso total pousado e baixa performance (poucos pousos) para negociar parcerias ou aquisições.
#
#
#
# *Mensurável (Measurable)*: Assinar pelo menos dois contratos de parceria ou aquisição de aeronaves com fabricantes, com base em insights de dados.
#
#
#
# *Atingível (Achievable)*: Utilizar a análise de dados para embasar negociações, focando em modelos que atendam às necessidades de rotas internacionais.
#
#
#
# *Relevante (Relevant)*: Parcerias estratégicas podem reduzir custos de aquisição e manutenção, além de melhorar a eficiência operacional.
#
#
#
# *Temporal (Time-bound)*: Concluir as parcerias em 24 meses, com negociações iniciadas no primeiro ano.
#
# **4. Melhorar a Previsão de Demanda em 20% em 12 Meses**
#
#
#
#
#
# *Específico (Specific)*: Desenvolver um modelo preditivo baseado em dados de tráfego aéreo para prever a demanda de rotas no SFO.
#
#
#
# *Mensurável (Measurable)*: Aumentar a precisão da previsão de demanda em 20%, medida pela redução de erros em relatórios de planejamento.
#
#
#
# *Atingível (Achievable)*: Utilizar dados históricos de pousos e técnicas de análise preditiva para criar um modelo robusto.
#
#
#
# *Relevante (Relevant)*: Uma previsão mais precisa melhora o planejamento de recursos e reduz custos com voos subutilizados.
#
#
#
# *Temporal (Time-bound)*: Implementar o modelo em 12 meses, com testes iniciais em 6 meses.

# %% [markdown]
# # 2. Entendimento dos Dados

# %% [markdown]
# ## 2.1 Este conjunto de dados contém os seguintes recursos:
#
#
# ![image.png](attachment:f257af13-30c3-4eee-98e4-a127f5b2e5ba.png)
#
# --- Segue o link com o arquivo completo:https://drive.google.com/file/d/1nWu5uBg4gb96uq05EKqARlWQPHOaWtw6/view?usp=sharing ----

# %% [markdown]
# ## 2.2 Tratamento dos dados

# %%
# Importação das bibliotecas necessárias

import pandas as pd
df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")
df
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507           ABX Air                          GB
# 1               200507           ABX Air                          GB
# 2               200507      ATA Airlines                          TZ
# 3               200507      ATA Airlines                          TZ
# 4               200507        Air Canada                          AC
# ...                ...               ...                         ...
# 26837           202109   United Airlines                          UA
# 26838           202109   United Airlines                          UA
# 26839           202109   United Airlines                          UA
# 26840           202109  WestJet Airlines                          WS
# 26841           202109  WestJet Airlines                          WS
#
#       Published Airline Published Airline IATA Code    GEO Summary  \
# 0               ABX Air                          GB       Domestic
# ...

# %%
# Visão Geral
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26842 entries, 0 to 26841
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              26842 non-null  int64
#  1   Operating Airline            26842 non-null  object
#  2   Operating Airline IATA Code  26738 non-null  object
#  3   Published Airline            26842 non-null  object
#  4   Published Airline IATA Code  26738 non-null  object
#  5   GEO Summary                  26842 non-null  object
#  6   GEO Region                   26842 non-null  object
#  7   Landing Aircraft Type        26842 non-null  object
#  8   Aircraft Body Type           26842 non-null  object
#  9   Aircraft Manufacturer        26825 non-null  object
#  10  Aircraft Model               26842 non-null  object
#  11  Aircraft Version             25684 non-null  object
#  12  Landing Count                26842 non-null  int64
# ...

# %% [markdown]
# **Interpretação**
#
# O conjunto de dados consiste em mais de 26.000 entradas. No entanto, há alguns dados ausentes. Aspectos como o Operating Airline IATA Code e Published Airline IATA Code  não são um problema significativo, pois as informações-chave relacionadas a essa variável estão armazenadas na variável Operating Airline.

# %%
# Visualizar valores nulos

df.isnull().sum().reset_index(name = "Null values").set_index("index")
# Out:
#                              Null values
# index
# Activity Period                        0
# Operating Airline                      0
# Operating Airline IATA Code          104
# Published Airline                      0
# Published Airline IATA Code          104
# GEO Summary                            0
# GEO Region                             0
# Landing Aircraft Type                  0
# Aircraft Body Type                     0
# Aircraft Manufacturer                 17
# Aircraft Model                         0
# Aircraft Version                    1158
# Landing Count                          0
# Total Landed Weight                    0

# %% [markdown]
# **Interpretação**
#
# No que diz respeito à versão da aeronave, as opções para recuperar os dados podem ser limitadas. Pode ser que, para algumas aeronaves, simplesmente não haja uma versão disponível.

# %%
print("O número de versões de aeronaves fornecidas é {}.".format(df["Aircraft Version"].nunique()))
# Out:
# O número de versões de aeronaves fornecidas é 90.

# %% [markdown]
# **Interpretação**
#
# Além disso, com base no peso total pousado, parece que houve algumas flutuações nos dados. Independentemente disso, informações de 90 versões de aeronaves estão fornecidas neste conjunto de dados, com algumas versões sendo extremamente populares em comparação com outras.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26842 entries, 0 to 26841
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              26842 non-null  datetime64[ns]
#  1   Operating Airline            26842 non-null  object
#  2   Operating Airline IATA Code  26738 non-null  object
#  3   Published Airline            26842 non-null  object
#  4   Published Airline IATA Code  26738 non-null  object
#  5   GEO Summary                  26842 non-null  object
#  6   GEO Region                   26842 non-null  object
#  7   Landing Aircraft Type        26842 non-null  object
#  8   Aircraft Body Type           26842 non-null  object
#  9   Aircraft Manufacturer        26825 non-null  object
#  10  Aircraft Model               26842 non-null  object
#  11  Aircraft Version             25684 non-null  object
# ...

# %%
# Convertendo Activity Period para o formato data
df['Activity Period'] = pd.to_datetime(df['Activity Period'], format='%Y%m')

# %%
print( f"O período dos dados analisados vai de {df['Activity Period'].min()} até {df['Activity Period'].max()}.")
# Out:
# O período dos dados analisados vai de 2005-07-01 00:00:00 até 2021-09-01 00:00:00.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26842 entries, 0 to 26841
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              26842 non-null  datetime64[ns]
#  1   Operating Airline            26842 non-null  object
#  2   Operating Airline IATA Code  26738 non-null  object
#  3   Published Airline            26842 non-null  object
#  4   Published Airline IATA Code  26738 non-null  object
#  5   GEO Summary                  26842 non-null  object
#  6   GEO Region                   26842 non-null  object
#  7   Landing Aircraft Type        26842 non-null  object
#  8   Aircraft Body Type           26842 non-null  object
#  9   Aircraft Manufacturer        26825 non-null  object
#  10  Aircraft Model               26842 non-null  object
#  11  Aircraft Version             25684 non-null  object
# ...

# %%
# Preencher valores nulos com "Não disponível" em todas as colunas
df = df.fillna("Não disponível")

# Verificar se ainda há valores nulos (opcional)
print(df.isnull().sum())
# Out:
# Activity Period                0
# Operating Airline              0
# Operating Airline IATA Code    0
# Published Airline              0
# Published Airline IATA Code    0
# GEO Summary                    0
# GEO Region                     0
# Landing Aircraft Type          0
# Aircraft Body Type             0
# Aircraft Manufacturer          0
# Aircraft Model                 0
# Aircraft Version               0
# Landing Count                  0
# Total Landed Weight            0
# dtype: int64

# %% [markdown]
# **Interpretação**
#
# *Premisa*: Resolvi padronizar as informações que estão em nulo para Não Disponivel.

# %%
# Visualizar valores nulos

df.isnull().sum().reset_index(name = "Null values").set_index("index")
# Out:
#                              Null values
# index
# Activity Period                        0
# Operating Airline                      0
# Operating Airline IATA Code            0
# Published Airline                      0
# Published Airline IATA Code            0
# GEO Summary                            0
# GEO Region                             0
# Landing Aircraft Type                  0
# Aircraft Body Type                     0
# Aircraft Manufacturer                  0
# Aircraft Model                         0
# Aircraft Version                       0
# Landing Count                          0
# Total Landed Weight                    0

# %%
# Listar todas as colunas do DataFrame

print("Colunas do DataFrame:")
print(df.columns)

# Verificar valores únicos para cada coluna

print("\nValores únicos por coluna:")

for coluna in df.columns:
    print(f"\nColuna: {coluna}")
    print(df[coluna].unique())
# Out:
# Colunas do DataFrame:
# Index(['Activity Period', 'Operating Airline', 'Operating Airline IATA Code',
#        'Published Airline', 'Published Airline IATA Code', 'GEO Summary',
#        'GEO Region', 'Landing Aircraft Type', 'Aircraft Body Type',
#        'Aircraft Manufacturer', 'Aircraft Model', 'Aircraft Version',
#        'Landing Count', 'Total Landed Weight'],
#       dtype='object')
#
# Valores únicos por coluna:
#
# Coluna: Activity Period
# <DatetimeArray>
# ['2005-07-01 00:00:00', '2005-08-01 00:00:00', '2005-09-01 00:00:00',
#  '2005-10-01 00:00:00', '2005-11-01 00:00:00', '2005-12-01 00:00:00',
#  '2006-01-01 00:00:00', '2006-02-01 00:00:00', '2006-03-01 00:00:00',
#  '2006-04-01 00:00:00',
#  ...
#  '2020-12-01 00:00:00', '2021-01-01 00:00:00', '2021-02-01 00:00:00',
#  '2021-03-01 00:00:00', '2021-04-01 00:00:00', '2021-05-01 00:00:00',
#  '2021-06-01 00:00:00', '2021-07-01 00:00:00', '2021-08-01 00:00:00',
#  '2021-09-01 00:00:00']
# ...

# %% [markdown]
# ## 3. Análise Unidimensional

# %% [markdown]
# ### 3.1 Activity Period

# %%
# Total

df["Activity Period"].value_counts()
# Out:
# Activity Period
# 2017-10-01    173
# 2017-06-01    168
# 2017-05-01    168
# 2019-03-01    167
# 2017-03-01    166
#              ...
# 2020-08-01     98
# 2020-07-01     95
# 2020-06-01     80
# 2020-04-01     79
# 2020-05-01     75
# Name: count, Length: 195, dtype: int64

# %%
# Total

df['Activity Period'].describe().to_frame().T
# Out:
#                  count                           mean                  min  \
# Activity Period  26842  2013-09-10 15:30:43.588406016  2005-07-01 00:00:00
#
#                                  25%                  50%  \
# Activity Period  2009-09-01 00:00:00  2013-11-01 00:00:00
#
#                                  75%                  max
# Activity Period  2017-09-01 00:00:00  2021-09-01 00:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Extrair a contagem de atividades por mês
activity_counts = df['Activity Period'].value_counts().sort_index()

# Criar um novo DataFrame com as datas e contagens
df_activity = pd.DataFrame({
    'Activity Period': activity_counts.index,
    'Count': activity_counts.values
})

# Converter a coluna 'Activity Period' para datetime
df_activity['Activity Period'] = pd.to_datetime(df_activity['Activity Period'])

# Plotar o gráfico de linha
plt.figure(figsize=(14, 6))
plt.plot(df_activity['Activity Period'], df_activity['Count'], marker='o', linestyle='-', color='b')

# Configurar os rótulos e título
plt.title('Contagem ao Longo do Tempo', fontsize=16)
plt.xlabel('Período de Atividade', fontsize=12)
plt.ylabel('Número de Atividades', fontsize=12)
plt.grid(True)

# Rotacionar os rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45)

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Estabilidade Pré-Pandemia (2008-2019):*
#
# De 2008 a 2019, o número de atividades de passageiros permaneceu relativamente estável, oscilando entre 120 e 160 atividades por mês.
#
# Houve pequenas flutuações mensais, mas nenhuma tendência significativa de aumento ou diminuição, indicando uma demanda consistente por viagens aéreas.
#
# *Crescimento Gradual (2014-2019):*
#
# A partir de 2014, há um aumento gradual no número de atividades de passageiros, atingindo um pico em 2019.
#
# Este período indica um crescimento constante nas operações de passageiros, possivelmente devido a fatores como expansão de rotas, aumento da frota ou maior demanda por viagens.
#
# *Impacto da Pandemia (2020):*
#
# Em 2020, há uma queda abrupta e dramática no número de atividades de passageiros, caindo para cerca de 80 atividades por mês.
#
# Este declínio é atribuído ao início da pandemia de COVID-19, que resultou em restrições de viagem, lockdowns e uma queda significativa na demanda por serviços aéreos.
#
# *Recuperação Pós-Pandemia (2021-2022):*
#
# Após a queda em 2020, há uma recuperação notável em 2021 e 2022.
#
# O número de atividades de passageiros começa a aumentar novamente, indicando uma retomada das operações à medida que as restrições de viagem são aliviadas e a demanda por serviços aéreos volta a crescer.
#
# *Análise Mensal:*
#
# A análise mensal mostra que as flutuações são mais pronunciadas em certos períodos do ano, possivelmente devido a estações de alta e baixa demanda (por exemplo, férias escolares, feriados).
#
# A queda em 2020 é particularmente acentuada em certos meses, refletindo o impacto imediato das restrições de viagem impostas durante a pandemia.
#
# *Conclusão:*
#
# O gráfico ilustra claramente o impacto significativo da pandemia de COVID-19 nas atividades de passageiros das companhias aéreas em 2020, seguido por uma recuperação gradual nos anos seguintes.
#
# A estabilidade pré-pandemia e o crescimento gradual indicam uma operação robusta e uma demanda consistente por viagens aéreas.
#
# A queda abrupta em 2020 destaca a vulnerabilidade do setor a eventos globais imprevistos, enquanto a recuperação pós-pandemia sugere uma resiliência e capacidade de adaptação da companhia aérea.

# %% [markdown]
# ### 3.2 Operating Airline

# %%
# Total

df["Operating Airline"].value_counts()
# Out:
# Operating Airline
# United Airlines                     3773
# United Airlines - Pre 07/01/2013    1834
# Alaska Airlines                     1613
# Delta Air Lines                     1599
# SkyWest Airlines                    1499
#                                     ...
# Pacific Aviation                       2
# Trego Dugan Aviation                   2
# E.A.G.L.E.                             1
# Xtra Airways                           1
# Boeing Company                         1
# Name: count, Length: 115, dtype: int64

# %%
# Total

df['Operating Airline'].describe().to_frame().T
# Out:
#                    count unique              top  freq
# Operating Airline  26842    115  United Airlines  3773

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np



# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Extrair a contagem de atividades por companhia aérea
airline_counts = df['Operating Airline'].value_counts()

# Criar um novo DataFrame com as companhias e contagens
df_airlines = pd.DataFrame({
    'Companhia Aérea': airline_counts.index,
    'Número de Atividades': airline_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_airlines = df_airlines.sort_values(by='Número de Atividades', ascending=False)

# Criar figura com tamanho adequado
plt.figure(figsize=(18, 10))

# GRÁFICO 1: Top 15 companhias aéreas (ao invés de 50 que ficava ilegível)
plt.subplot(1, 2, 1)
top_15 = df_airlines.head(15)
bars = plt.barh(top_15['Companhia Aérea'], top_15['Número de Atividades'], 
         color=sns.color_palette("Blues_d", 15))

# Adicionar valores nas barras
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f'{top_15["Número de Atividades"].iloc[i]:,}',
             va='center', fontsize=9)

plt.title('Top 15 Companhias Aéreas por Volume de Atividades', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# GRÁFICO 2: Distribuição por grupos de companhias
plt.subplot(1, 2, 2)

# Criar grupos mais significativos
top_10 = df_airlines.head(10)
next_10 = df_airlines.iloc[10:20]
other_airlines = df_airlines.iloc[20:]

# Criar dados agregados para o gráfico de pizza
sizes = [
    top_10['Número de Atividades'].sum(),
    next_10['Número de Atividades'].sum(),
    other_airlines['Número de Atividades'].sum()
]

labels = [
    f'Top 10 Companhias\n{sizes[0]:,} atividades ({sizes[0]/sum(sizes):.1%})',
    f'Companhias 11-20\n{sizes[1]:,} atividades ({sizes[1]/sum(sizes):.1%})',
    f'Outras Companhias\n{sizes[2]:,} atividades ({sizes[2]/sum(sizes):.1%})'
]

# Criar gráfico de pizza com espaçamento entre as fatias
explode = (0.05, 0.05, 0.05)
wedges, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', 
                                   startangle=90, explode=explode, 
                                   shadow=True, textprops={'fontsize': 11})

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

plt.axis('equal')
plt.title('Distribuição de Atividades por Grupo de Companhias', fontsize=14, fontweight='bold')

# Adicionar detalhes das top 5 companhias em uma caixa de texto
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
top_5_info = "\n".join([f"{row['Companhia Aérea']}: {row['Número de Atividades']:,}" 
                        for _, row in top_15.head(5).iterrows()])
plt.text(1.4, 0, 'Top 5 Companhias:\n\n' + top_5_info, fontsize=10,
         verticalalignment='top', horizontalalignment='center',
         transform=plt.gca().transAxes, bbox=props)

# Ajustes finais
plt.tight_layout()
plt.suptitle('Análise de atividades de passageiros por Companhia Aérea', fontsize=16, fontweight='bold', y=1.02)

# Adicionar informações úteis no rodapé
plt.figtext(0.5, -0.01, 'Total de companhias analisadas: ' + str(len(df_airlines)) + 
            ' | Total de atividades: ' + f'{df_airlines["Número de Atividades"].sum():,}',
            ha='center', fontsize=10)

plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# **Interpretação**
#
#
#   *Domínio das Top 10 Companhias Aéreas:*
#
# As top 10 companhias aéreas representam 52,8% do total de atividades de passageiros, com um total de 14.167 atividades.
#
# Isso indica uma concentração significativa de atividades entre um número relativamente pequeno de companhias aéreas.
#
# *Distribuição das Atividades:*
#
# *Top 5 Companhias Aéreas:*
#
# United Airlines: 3.773 atividades
#
# United Airlines - Pré 07/01/2013: 1.834 atividades
#
# Alaska Airlines: 1.613 atividades
#
# Delta Air Lines: 1.599 atividades
#
# SkyWest Airlines: 1.499 atividades
#
# Essas cinco companhias aéreas sozinhas representam uma parcela substancial das atividades de passageiros, destacando sua posição dominante no mercado.
# Outras Companhias Aéreas:
#
# As outras companhias aéreas (fora das top 10) representam 32,1% das atividades, com um total de 8.603 atividades.
#
# Companhias aéreas classificadas entre a 11ª e a 20ª posição representam 15,2% das atividades, com um total de 4.072 atividades.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa nas top 10 companhias aéreas, com uma queda acentuada nas atividades à medida que se desce na lista.
#
# Isso sugere que um pequeno número de companhias aéreas domina o mercado, enquanto uma longa cauda de companhias aéreas menores compartilha o restante das atividades.
#
# *Comparação entre Companhias Aéreas:*
#
# United Airlines lidera com uma margem significativa, tendo quase o dobro das atividades da próxima companhia aérea na lista (United Airlines - Pré 07/01/2013).
#
# Há uma diferença notável entre as atividades das top 5 companhias aéreas e as demais, indicando uma competição acirrada no topo do mercado.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades de passageiros entre as top 10 companhias aéreas, com as top 5 companhias aéreas dominando o mercado. A distribuição das atividades mostra uma queda acentuada à medida que se desce na lista, destacando a posição dominante de um pequeno número de companhias aéreas. Isso sugere uma competição intensa no topo do mercado e uma longa

# %% [markdown]
# ## 3.3 Operating Airline IATA Code

# %%
# Total

df["Operating Airline IATA Code"].value_counts()
# Out:
# Operating Airline IATA Code
# UA    5607
# AS    1613
# DL    1599
# OO    1499
# AA    1055
#       ...
# IG       7
# DH       5
# 5X       4
# 4T       3
# XP       1
# Name: count, Length: 103, dtype: int64

# %%
# Total

df['Operating Airline IATA Code'].describe().to_frame().T
# Out:
#                              count unique top  freq
# Operating Airline IATA Code  26842    103  UA  5607

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Extrair a contagem de atividades por código IATA
iata_code_counts = df['Operating Airline IATA Code'].value_counts()

# Criar um novo DataFrame com os códigos IATA e contagens
df_iata = pd.DataFrame({
    'Código IATA': iata_code_counts.index,
    'Número de Atividades': iata_code_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_iata = df_iata.sort_values(by='Número de Atividades', ascending=False)

# Criar figura com tamanho adequado
plt.figure(figsize=(18, 10))

# GRÁFICO 1: Top 15 códigos IATA (ao invés de 50 que ficava ilegível)
plt.subplot(1, 2, 1)
top_15 = df_iata.head(15)
bars = plt.barh(top_15['Código IATA'], top_15['Número de Atividades'], 
         color=sns.color_palette("Blues_d", 15))

# Adicionar valores nas barras
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f'{top_15["Número de Atividades"].iloc[i]:,}',
             va='center', fontsize=9)

plt.title('Top 15 Códigos IATA por Volume de Atividades', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# GRÁFICO 2: Distribuição por grupos de códigos IATA
plt.subplot(1, 2, 2)

# Criar grupos mais significativos
top_10 = df_iata.head(10)
next_10 = df_iata.iloc[10:20]
other_codes = df_iata.iloc[20:]

# Criar dados agregados para o gráfico de pizza
sizes = [
    top_10['Número de Atividades'].sum(),
    next_10['Número de Atividades'].sum(),
    other_codes['Número de Atividades'].sum()
]

labels = [
    f'Top 10 Códigos\n{sizes[0]:,} atividades ({sizes[0]/sum(sizes):.1%})',
    f'Códigos 11-20\n{sizes[1]:,} atividades ({sizes[1]/sum(sizes):.1%})',
    f'Outros Códigos\n{sizes[2]:,} atividades ({sizes[2]/sum(sizes):.1%})'
]

# Criar gráfico de pizza com espaçamento entre as fatias
explode = (0.05, 0.05, 0.05)
wedges, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', 
                                   startangle=90, explode=explode, 
                                   shadow=True, textprops={'fontsize': 11})

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

plt.axis('equal')
plt.title('Distribuição de Atividades por Grupo de Códigos IATA', fontsize=14, fontweight='bold')

# Adicionar detalhes dos top 5 códigos em uma caixa de texto
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
top_5_info = "\n".join([f"{row['Código IATA']}: {row['Número de Atividades']:,}" 
                        for _, row in top_15.head(5).iterrows()])
plt.text(1.4, 0, 'Top 5 Códigos IATA:\n\n' + top_5_info, fontsize=10,
         verticalalignment='top', horizontalalignment='center',
         transform=plt.gca().transAxes, bbox=props)

# Ajustes finais
plt.tight_layout()
plt.suptitle('Análise por Código IATA', fontsize=16, fontweight='bold', y=1.02)

# Adicionar informações úteis no rodapé
plt.figtext(0.5, -0.01, 'Total de códigos IATA analisados: ' + str(len(df_iata)) + 
            ' | Total de atividades: ' + f'{df_iata["Número de Atividades"].sum():,}',
            ha='center', fontsize=10)

plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Domínio dos Top 10 Códigos IATA:*
#
# Os top 10 códigos IATA representam 54,6% do total de atividades de passageiros, com um total de 14.648 atividades.
#
# Isso indica uma concentração significativa de atividades entre um número relativamente pequeno de códigos IATA.
#
# *Distribuição das Atividades:*
#
# *Top 5 Códigos IATA:*
# UA (United Airlines): 5.607 atividades
#
# AS (Alaska Airlines): 1.613 atividades
#
# DL (Delta Air Lines): 1.599 atividades
#
# OO (SkyWest Airlines): 1.499 atividades
#
# AA (American Airlines): 1.055 atividades
#
# Esses cinco códigos IATA sozinhos representam uma parcela substancial das atividades de passageiros, destacando sua posição dominante no mercado.
#
# *Outros Códigos IATA:*
#
# Os outros códigos IATA (fora dos top 10) representam 30,8% das atividades, com um total de 8.262 atividades.
#
# Códigos IATA classificados entre a 11ª e a 20ª posição representam 14,6% das atividades, com um total de 3.932 atividades.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa nos top 10 códigos IATA, com uma queda acentuada nas atividades à medida que se desce na lista.
# Isso sugere que um pequeno número de códigos IATA domina o mercado, enquanto uma longa cauda de códigos IATA menores compartilha o restante das atividades.
#
# *Comparação entre Códigos IATA:*
#
# O código IATA UA (United Airlines) lidera com uma margem significativa, tendo quase o dobro das atividades do próximo código IATA na lista (AS - Alaska Airlines).
#
# Há uma diferença notável entre as atividades dos top 5 códigos IATA e os demais, indicando uma competição acirrada no topo do mercado.
#
# *Conclusão:*
# O gráfico ilustra uma concentração significativa de atividades de passageiros entre os top 10 códigos IATA, com os top 5 códigos IATA dominando o mercado.
# A distribuição das atividades mostra uma queda acentuada à medida que se desce na lista, destacando a posição dominante de um pequeno número de códigos IATA.
# Isso sugere uma competição intensa no topo do mercado e uma longa cauda de códigos IATA menores compartilhando o restante das atividades

# %% [markdown]
# ## 3.4 Published Airline

# %%
# Total

df["Published Airline"].value_counts()
# Out:
# Published Airline
# United Airlines                     4348
# United Airlines - Pre 07/01/2013    2274
# Delta Air Lines                     2148
# Alaska Airlines                     1838
# American Airlines                   1198
#                                     ...
# Pacific Aviation                       2
# Trego Dugan Aviation                   2
# E.A.G.L.E.                             1
# Boeing Company                         1
# Xtra Airways                           1
# Name: count, Length: 105, dtype: int64

# %%
# Total

df['Published Airline'].describe().to_frame().T
# Out:
#                    count unique              top  freq
# Published Airline  26842    105  United Airlines  4348

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Extrair a contagem de atividades por companhia aérea
airline_counts = df['Published Airline'].value_counts()

# Criar um novo DataFrame com as companhias aéreas e contagens
df_airlines = pd.DataFrame({
    'Companhia Aérea': airline_counts.index,
    'Número de Atividades': airline_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_airlines = df_airlines.sort_values(by='Número de Atividades', ascending=False)

# Criar figura com tamanho adequado
plt.figure(figsize=(18, 10))

# GRÁFICO 1: Top 15 companhias aéreas (ao invés de 50 que ficava ilegível)
plt.subplot(1, 2, 1)
top_15 = df_airlines.head(15)
bars = plt.barh(top_15['Companhia Aérea'], top_15['Número de Atividades'], 
         color=sns.color_palette("Blues_d", 15))

# Adicionar valores nas barras
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f'{top_15["Número de Atividades"].iloc[i]:,}',
             va='center', fontsize=9)

plt.title('Top 15 Companhias Aéreas por Volume de Atividades', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# GRÁFICO 2: Distribuição por grupos de companhias
plt.subplot(1, 2, 2)

# Criar grupos mais significativos
top_10 = df_airlines.head(10)
next_10 = df_airlines.iloc[10:20]
other_airlines = df_airlines.iloc[20:]

# Criar dados agregados para o gráfico de pizza
sizes = [
    top_10['Número de Atividades'].sum(),
    next_10['Número de Atividades'].sum(),
    other_airlines['Número de Atividades'].sum()
]

labels = [
    f'Top 10 Companhias\n{sizes[0]:,} atividades ({sizes[0]/sum(sizes):.1%})',
    f'Companhias 11-20\n{sizes[1]:,} atividades ({sizes[1]/sum(sizes):.1%})',
    f'Outras Companhias\n{sizes[2]:,} atividades ({sizes[2]/sum(sizes):.1%})'
]

# Criar gráfico de pizza com espaçamento entre as fatias
explode = (0.05, 0.05, 0.05)
wedges, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', 
                                   startangle=90, explode=explode, 
                                   shadow=True, textprops={'fontsize': 11})

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

plt.axis('equal')
plt.title('Distribuição de Atividades por Grupo de Companhias', fontsize=14, fontweight='bold')

# Adicionar detalhes das top 5 companhias em uma caixa de texto
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
top_5_info = "\n".join([f"{row['Companhia Aérea']}: {row['Número de Atividades']:,}" 
                        for _, row in top_15.head(5).iterrows()])
plt.text(1.4, 0, 'Top 5 Companhias:\n\n' + top_5_info, fontsize=10,
         verticalalignment='top', horizontalalignment='center',
         transform=plt.gca().transAxes, bbox=props)

# Ajustes finais
plt.tight_layout()
plt.suptitle('Análise da Companhia Aérea que emite e registra a receita', fontsize=16, fontweight='bold', y=1.02)

# Adicionar informações úteis no rodapé
plt.figtext(0.5, -0.01, 'Total de companhias analisadas: ' + str(len(df_airlines)) + 
            ' | Total de atividades: ' + f'{df_airlines["Número de Atividades"].sum():,}',
            ha='center', fontsize=10)

plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Domínio das Top 10 Companhias Aéreas:*
#
# As top 10 companhias aéreas representam 56,7% do total de atividades de passageiros, com um total de 15.223 atividades.
#
# Isso indica uma concentração significativa de atividades entre um número relativamente pequeno de companhias aéreas.
#
# *Distribuição das Atividades:*
#
# *Top 5 Companhias Aéreas:*
#
# United Airlines: 4.348 atividades
#
# United Airlines - Pré 07/01/2013: 2.274 atividades
#
# Delta Air Lines: 2.148 atividades
#
# Alaska Airlines: 1.838 atividades
#
# American Airlines: 1.198 atividades
#
# Essas cinco companhias aéreas sozinhas representam uma parcela substancial das atividades de passageiros, destacando sua posição dominante no mercado.
#
# *Outras Companhias Aéreas:*
#
# As outras companhias aéreas (fora das top 10) representam 28,6% das atividades, com um total de 7.687 atividades.
#
# Companhias aéreas classificadas entre a 11ª e a 20ª posição representam 14,6% das atividades, com um total de 3.932 atividades.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa nas top 10 companhias aéreas, com uma queda acentuada nas atividades à medida que se desce na lista.
#
# Isso sugere que um pequeno número de companhias aéreas domina o mercado, enquanto uma longa cauda de companhias aéreas menores compartilha o restante das atividades.
#
# *Comparação entre Companhias Aéreas:*
#
# United Airlines lidera com uma margem significativa, tendo quase o dobro das atividades da próxima companhia aérea na lista (United Airlines - Pré 07/01/2013).
#
# Há uma diferença notável entre as atividades das top 5 companhias aéreas e as demais, indicando uma competição acirrada no topo do mercado.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades de passageiros entre as top 10 companhias aéreas, com as top 5 companhias aéreas dominando o mercado.
# A distribuição das atividades mostra uma queda acentuada à medida que se desce na lista, destacando a posição dominante de um pequeno número de companhias aéreas.
# Isso sugere uma competição intensa no topo do mercado e uma longa cauda de companhias aéreas menores compartilhando o restante das atividades.

# %% [markdown]
# ## 3.5 Published Airline IATA Code

# %%
# Total

df["Published Airline IATA Code"].value_counts()
# Out:
# Published Airline IATA Code
# UA    6622
# DL    2148
# AS    1838
# AA    1198
# AC    1063
#       ...
# IG       7
# DH       5
# 5X       4
# 4T       3
# XP       1
# Name: count, Length: 94, dtype: int64

# %%
# Total

df['Published Airline IATA Code'].describe().to_frame().T
# Out:
#                              count unique top  freq
# Published Airline IATA Code  26842     94  UA  6622

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Extrair a contagem de atividades por código IATA da coluna 'Published Airline IATA Code'
iata_code_counts = df['Published Airline IATA Code'].value_counts()

# Criar um novo DataFrame com os códigos IATA e contagens
df_iata = pd.DataFrame({
    'Código IATA': iata_code_counts.index,
    'Número de Atividades': iata_code_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_iata = df_iata.sort_values(by='Número de Atividades', ascending=False)

# Criar figura com tamanho adequado
plt.figure(figsize=(18, 10))

# GRÁFICO 1: Top 15 códigos IATA (ao invés de 50 que ficava ilegível)
plt.subplot(1, 2, 1)
top_15 = df_iata.head(15)
bars = plt.barh(top_15['Código IATA'], top_15['Número de Atividades'], 
         color=sns.color_palette("Blues_d", 15))

# Adicionar valores nas barras
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f'{top_15["Número de Atividades"].iloc[i]:,}',
             va='center', fontsize=9)

plt.title('Top 15 Códigos IATA Publicados por Volume de Atividades', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.ylabel('Código IATA', fontsize=12)
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# GRÁFICO 2: Distribuição por grupos de códigos IATA
plt.subplot(1, 2, 2)

# Criar grupos mais significativos
top_10 = df_iata.head(10)
next_10 = df_iata.iloc[10:20]
other_codes = df_iata.iloc[20:]

# Criar dados agregados para o gráfico de pizza
sizes = [
    top_10['Número de Atividades'].sum(),
    next_10['Número de Atividades'].sum(),
    other_codes['Número de Atividades'].sum()
]

labels = [
    f'Top 10 Códigos\n{sizes[0]:,} atividades ({sizes[0]/sum(sizes):.1%})',
    f'Códigos 11-20\n{sizes[1]:,} atividades ({sizes[1]/sum(sizes):.1%})',
    f'Outros Códigos\n{sizes[2]:,} atividades ({sizes[2]/sum(sizes):.1%})'
]

# Criar gráfico de pizza com espaçamento entre as fatias
explode = (0.05, 0.05, 0.05)
wedges, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', 
                                   startangle=90, explode=explode, 
                                   shadow=True, textprops={'fontsize': 11})

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

plt.axis('equal')
plt.title('Distribuição de Atividades por Grupo de Códigos IATA Publicados', fontsize=14, fontweight='bold')

# Adicionar detalhes dos top 5 códigos em uma caixa de texto
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
top_5_info = "\n".join([f"{row['Código IATA']}: {row['Número de Atividades']:,}" 
                        for _, row in top_15.head(5).iterrows()])
plt.text(1.4, 0, 'Top 5 Códigos IATA:\n\n' + top_5_info, fontsize=10,
         verticalalignment='top', horizontalalignment='center',
         transform=plt.gca().transAxes, bbox=props)

# Ajustes finais
plt.tight_layout()
plt.suptitle('Análise da Companhia Aérea que emite e registra a receita por Código IATA', fontsize=16, fontweight='bold', y=1.02)

# Adicionar informações úteis no rodapé
plt.figtext(0.5, -0.01, 'Total de códigos IATA analisados: ' + str(len(df_iata)) + 
            ' | Total de atividades: ' + f'{df_iata["Número de Atividades"].sum():,}',
            ha='center', fontsize=10)

plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Domínio dos Top 10 Códigos IATA:*
#
# Os top 10 códigos IATA representam 58,5% do total de atividades de passageiros, com um total de 15.691 atividades.
#
# Isso indica uma concentração significativa de atividades entre um número relativamente pequeno de códigos IATA.
#
# *Distribuição das Atividades:*
#
#
#
# *Top 5 Códigos IATA:*
#
# UA (United Airlines): 6.622 atividades
#
# DL (Delta Air Lines): 2.148 atividades
#
# AS (Alaska Airlines): 1.838 atividades
#
# AA (American Airlines): 1.198 atividades
#
# AC (Air Canada): 1.063 atividades
#
# Esses cinco códigos IATA sozinhos representam uma parcela substancial das atividades de passageiros, destacando sua posição dominante no mercado.
#
# *Outros Códigos IATA:*
#
# Os outros códigos IATA (fora dos top 10) representam 27,4% das atividades, com um total de 7.347 atividades.
#
# Códigos IATA classificados entre a 11ª e a 20ª posição representam 14,2% das atividades, com um total de 3.804 atividades.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa nos top 10 códigos IATA, com uma queda acentuada nas atividades à medida que se desce na lista.
#
# Isso sugere que um pequeno número de códigos IATA domina o mercado, enquanto uma longa cauda de códigos IATA menores compartilha o restante das atividades.
#
# *Comparação entre Códigos IATA:*
#
# O código IATA UA (United Airlines) lidera com uma margem significativa, tendo quase o dobro das atividades do próximo código IATA na lista (DL - Delta Air Lines).
#
# Há uma diferença notável entre as atividades dos top 5 códigos IATA e os demais, indicando uma competição acirrada no topo do mercado.
#
# *Conclusão:*
# O gráfico ilustra uma concentração significativa de atividades de passageiros entre os top 10 códigos IATA, com os top 5 códigos IATA dominando o mercado.
# A distribuição das atividades mostra uma queda acentuada à medida que se desce na lista, destacando a posição dominante de um pequeno número de códigos IATA.
# Isso sugere uma competição intensa no topo do mercado e uma longa cauda de códigos IATA menores compartilhando o restante das atividades.

# %% [markdown]
# ## 3.6 GEO Summary

# %%
# Total

df["GEO Summary"].value_counts()
# Out:
# GEO Summary
# International    14057
# Domestic         12785
# Name: count, dtype: int64

# %%
# Total

df['GEO Summary'].describe().to_frame().T
# Out:
#              count unique            top   freq
# GEO Summary  26842      2  International  14057

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Extrair a contagem de atividades por GEO Summary
geo_summary_counts = df['GEO Summary'].value_counts()

# Criar um novo DataFrame com as categorias e contagens
df_geo_summary = pd.DataFrame({
    'GEO Summary': geo_summary_counts.index,
    'Count': geo_summary_counts.values
})

# Plotar o gráfico de setores (pizza)
plt.figure(figsize=(8, 6))
plt.pie(df_geo_summary['Count'], labels=df_geo_summary['GEO Summary'], autopct='%1.1f%%', 
        startangle=90, colors=['skyblue', 'lightcoral'], explode=[0.1, 0], shadow=True)

# Configurar os rótulos e título
plt.title('Distribuição de Atividades por GEO Summary', fontsize=16)
plt.axis('equal')  # Garante que o gráfico seja um círculo perfeito

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Interpretação**
#
#
#   *Distribuição das Atividades:*
#
# *Atividades Internacionais:*
#
# Representam 52,4% do total de atividades de passageiros.
#
# Isso indica que mais da metade das atividades de passageiros são relacionadas a voos internacionais.
#
# *Atividades Domésticas:*
#
# Representam 47,6% do total de atividades de passageiros.
#
# Isso mostra que quase metade das atividades de passageiros são relacionadas a voos domésticos.
#
# *Equilíbrio entre Internacional e Doméstico:*
#
# A distribuição das atividades é relativamente equilibrada entre voos internacionais e domésticos, com uma ligeira predominância das atividades internacionais.
#
# Isso sugere que a companhia aérea ou o conjunto de dados analisado tem uma presença significativa tanto em rotas internacionais quanto domésticas.
#
# *Foco Operacional:*
#
# A maior parte das atividades está concentrada em voos internacionais, indicando um foco operacional em rotas que conectam diferentes países.
#
# No entanto, a proporção significativa de atividades domésticas mostra que as rotas nacionais também são uma parte importante das operações.
#
# *Impacto Econômico e Operacional:*
#
# Voos internacionais geralmente envolvem maiores distâncias, tempos de voo e custos operacionais, o que pode refletir em uma maior receita por atividade.
#
# Voos domésticos, por outro lado, podem ser mais frequentes e ter menores distâncias, o que pode resultar em uma maior eficiência operacional e menores custos.
#
# *Conclusão:*
#
# O gráfico ilustra uma distribuição equilibrada das atividades de passageiros entre voos internacionais e domésticos, com uma ligeira predominância das atividades internacionais.
# Isso sugere que a companhia aérea ou o conjunto de dados analisado tem uma presença significativa tanto em rotas internacionais quanto domésticas, indicando um foco operacional diversificado.
# A maior parte das atividades está concentrada em voos internacionais, o que pode refletir um maior potencial de receita, enquanto as atividades domésticas também desempenham um papel importante nas operações.

# %% [markdown]
# ## 3.7 GEO Region

# %%
# Total

df["GEO Region"].value_counts()
# Out:
# GEO Region
# US                     12838
# Asia                    5098
# Europe                  3094
# Canada                  2382
# Mexico                  1882
# Australia / Oceania      864
# Central America          419
# Middle East              212
# South America             50
# Caribbean                  3
# Name: count, dtype: int64

# %%
# Total

df['GEO Region'].describe().to_frame().T
# Out:
#             count unique top   freq
# GEO Region  26842     10  US  12838

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Extrair a contagem de atividades por região geográfica
region_counts = df['GEO Region'].value_counts()

# Criar um novo DataFrame com as regiões e contagens
df_regions = pd.DataFrame({
    'GEO Region': region_counts.index,
    'Count': region_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_regions = df_regions.sort_values(by='Count', ascending=False)

# Criar figura com tamanho adequado
plt.figure(figsize=(10, 6))

# Plotar o gráfico de barras horizontais
bars = plt.barh(df_regions['GEO Region'], df_regions['Count'], color=sns.color_palette("Blues_d", len(df_regions)))

# Adicionar valores nas barras
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f'{df_regions["Count"].iloc[i]:,}',
             va='center', fontsize=9)

# Configurar os rótulos e título
plt.title('Distribuição por Região Geográfica refente a chegadas e partidas no SFO Sem escalas', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.ylabel('Região Geográfica', fontsize=12)

# Rotacionar os rótulos do eixo y para melhor legibilidade
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Ajustar layout
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Interpretação**
#
#     *Domínio das Regiões Geográficas:*
#
# *Estados Unidos (US):*
#
# Representa a maior parte das atividades, com um total de 12.838 atividades.
#
# Isso indica uma concentração significativa de atividades de passageiros nos Estados Unidos, sugerindo que é uma região chave para as operações da companhia aérea.
#
# *Ásia:*
#
# A segunda região com maior número de atividades, totalizando 5.098.
#
# Isso mostra que a Ásia também é uma região importante para as operações da companhia aérea.
#
# *Europa:*
#
# Com 3.094 atividades, a Europa é a terceira região mais ativa.
#
# Isso indica uma presença significativa de atividades de passageiros na Europa.
#
# *Distribuição das Atividades:*
#
# *América do Norte (US, Canadá, México):*
#
# A soma das atividades nos Estados Unidos, Canadá e México é significativa, destacando a importância da América do Norte para as operações da companhia aérea.
#
# *Outras Regiões:*
#
# Austrália/Oceania, América Central, Oriente Médio, América do Sul e Caribe têm um número muito menor de atividades, indicando uma presença menos significativa nessas regiões.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa nas regiões dos Estados Unidos, Ásia e Europa.
#
# Isso sugere que a companhia aérea tem um foco operacional forte nessas regiões, possivelmente devido a fatores como demanda de passageiros, hubs de conexão e estratégias de mercado.
#
# *Comparação entre Regiões:*
#
# Os Estados Unidos lideram com uma margem significativa, tendo mais do que o dobro das atividades da próxima região na lista (Ásia).
#
# Há uma diferença notável entre as atividades nas regiões mais ativas (Estados Unidos, Ásia, Europa) e as demais, indicando uma competição acirrada e um foco operacional nas regiões mais ativas.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades de passageiros nas regiões dos Estados Unidos, Ásia e Europa, com os Estados Unidos liderando com uma margem considerável.
# A distribuição das atividades mostra uma queda acentuada à medida que se desce na lista, destacando a posição dominante dessas regiões.
# Isso sugere uma competição intensa e um foco operacional nas regiões mais ativas, enquanto outras regiões têm uma presença menos significativa nas operações da companhia aérea.

# %% [markdown]
# ## 3.8 Landing Aircraft Type

# %%
# Total

df["Landing Aircraft Type"].value_counts()
# Out:
# Landing Aircraft Type
# Passenger    23690
# Freighter     3010
# Combi          142
# Name: count, dtype: int64

# %%
# Total

df['Landing Aircraft Type'].describe().to_frame().T
# Out:
#                        count unique        top   freq
# Landing Aircraft Type  26842      3  Passenger  23690

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supondo que você já tenha o DataFrame 'df' carregado
# df = pd.read_csv('seu_arquivo.csv')  # Caso precise carregar o arquivo

# Extrair a contagem de atividades por Landing Aircraft Type
aircraft_type_counts = df['Landing Aircraft Type'].value_counts()

# Criar um novo DataFrame com os tipos de aeronaves e contagens
df_aircraft_types = pd.DataFrame({
    'Landing Aircraft Type': aircraft_type_counts.index,
    'Count': aircraft_type_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_aircraft_types = df_aircraft_types.sort_values(by='Count', ascending=False)

# Calcular as porcentagens
total_activities = df_aircraft_types['Count'].sum()
df_aircraft_types['Percentage'] = (df_aircraft_types['Count'] / total_activities) * 100

# Definir cores personalizadas (sem vermelho)
colors = {
    'Passenger': 'skyblue',
    'Freighter': 'orange',  # Substituído por laranja claro
    'Combi': 'lightgreen'
}

# Plotar o gráfico de barras horizontais
plt.figure(figsize=(8, 6))
bars = plt.barh(df_aircraft_types['Landing Aircraft Type'], df_aircraft_types['Count'], 
                color=[colors[category] for category in df_aircraft_types['Landing Aircraft Type']])

# Adicionar valores absolutos dentro das barras e porcentagens fora
for i, bar in enumerate(bars):
    count = df_aircraft_types['Count'].iloc[i]
    percentage = df_aircraft_types['Percentage'].iloc[i]
    category = df_aircraft_types['Landing Aircraft Type'].iloc[i]
    
    # Valor absoluto dentro da barra (exceto para Combi)
    if category != 'Combi':
        plt.text(bar.get_width() / 2, bar.get_y() + bar.get_height()/2, 
                 f"{count:,}",  # Apenas o valor absoluto
                 ha='center', va='center', fontsize=9, color='black')
    
    # Porcentagem fora da barra
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f"({percentage:.1f}%)",  # Apenas a porcentagem
             va='center', fontsize=9, color='black')

# Configurar os rótulos e título
plt.title('Distribuição por Tipo de Aeronave que pousou no SFO', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.ylabel('Tipo de Aeronave', fontsize=12)

# Rotacionar os rótulos do eixo y para melhor legibilidade
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Ajustar layout
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Domínio das Aeronaves de Passageiros:*
#
# *Aeronaves de Passageiros:*
#
# Representam a maioria esmagadora das atividades, com um total de 23.690 atividades, correspondendo a 88,3% do total.
#
# Isso indica que a grande maioria das aeronaves que pousam no SFO são destinadas ao transporte de passageiros.
#
# *Presença de Aeronaves de Carga:*
#
# *Aeronaves de Carga (Freighter):*
#
# Representam 3.010 atividades, correspondendo a 11,2% do total.
#
# Embora seja uma parcela menor em comparação com as aeronaves de passageiros, ainda é significativa e indica a importância do transporte de carga no aeroporto.
#
# *Aeronaves Combinadas (Combi):*
#
# *Aeronaves Combinadas:*
#
# Representam apenas 0,5% do total de atividades, com um número muito pequeno de atividades.
#
# Isso sugere que aeronaves que transportam tanto passageiros quanto carga são raras no SFO.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa em aeronaves de passageiros, seguidas por aeronaves de carga, com uma presença mínima de aeronaves combinadas.
#
# Isso reflete a principal função do aeroporto como um hub para o transporte de passageiros, com uma parte significativa das operações dedicadas ao transporte de carga.
#
# *Comparação entre Tipos de Aeronaves:*
#
# As aeronaves de passageiros dominam com uma margem significativa, tendo mais de sete vezes o número de atividades das aeronaves de carga.
#
# A diferença entre as atividades de aeronaves de passageiros e as demais é notável, indicando um foco operacional claro no transporte de passageiros.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades de aeronaves de passageiros no Aeroporto Internacional de São Francisco (SFO), com uma parcela menor, mas ainda significativa, de atividades de aeronaves de carga. A presença de aeronaves combinadas é mínima.
# Isso sugere que o SFO é principalmente um hub para o transporte de passageiros, com uma parte importante das operações dedicadas ao transporte de carga.
# A distribuição das atividades reflete a principal função do aeroporto e destaca a importância do transporte de passageiros nas operações do SFO.

# %% [markdown]
# ## 3.9 Aircraft Body Type

# %%
# Total

df["Aircraft Body Type"].value_counts()
# Out:
# Aircraft Body Type
# Wide Body       12828
# Narrow Body     11379
# Regional Jet     2129
# Turbo Prop        506
# Name: count, dtype: int64

# %%
# Total

df['Aircraft Body Type'].describe().to_frame().T
# Out:
#                     count unique        top   freq
# Aircraft Body Type  26842      4  Wide Body  12828

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supondo que você já tenha o DataFrame 'df' carregado
# df = pd.read_csv('seu_arquivo.csv')  # Caso precise carregar o arquivo

# Extrair a contagem de atividades por Aircraft Body Type
body_type_counts = df['Aircraft Body Type'].value_counts()

# Criar um novo DataFrame com os tipos de fuselagem e contagens
df_body_types = pd.DataFrame({
    'Aircraft Body Type': body_type_counts.index,
    'Count': body_type_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_body_types = df_body_types.sort_values(by='Count', ascending=False)

# Definir cores personalizadas para cada tipo de fuselagem (sem vermelho)
colors = {
    'Wide Body': 'skyblue',
    'Narrow Body': 'lightgreen',
    'Regional Jet': 'orange',
    'Turbo Prop': 'lightcoral'
}

# Plotar o gráfico de barras horizontais
plt.figure(figsize=(10, 6))
bars = plt.barh(df_body_types['Aircraft Body Type'], df_body_types['Count'], 
                color=[colors[category] for category in df_body_types['Aircraft Body Type']])

# Adicionar valores absolutos dentro das barras
for i, bar in enumerate(bars):
    count = df_body_types['Count'].iloc[i]
    plt.text(bar.get_width() / 2, bar.get_y() + bar.get_height()/2, 
             f"{count:,}",  # Apenas o valor absoluto
             ha='center', va='center', fontsize=9, color='black')

# Configurar os rótulos e título
plt.title('Distribuição por Tipo de Fuselagem', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.ylabel('Tipo de Fuselagem', fontsize=12)

# Rotacionar os rótulos do eixo y para melhor legibilidade
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Ajustar layout para evitar sobreposições
plt.tight_layout()
plt.subplots_adjust(left=0.3)  # Aumentar o espaço à esquerda para evitar cortes nos rótulos

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Domínio das Aeronaves Wide Body:*
#
# *Wide Body:*
#
# Representam a maior parte das atividades, com um total de 12.828 atividades.
#
# Isso indica que as aeronaves de fuselagem larga (wide body) são as mais comuns no SFO, provavelmente devido à sua capacidade de transportar um maior número de passageiros e carga em voos de longa distância.
#
# *Presença Significativa de Aeronaves Narrow Body:*
#
# *Narrow Body:*
#
# Representam 11.379 atividades, uma quantidade significativa, mas ligeiramente menor que as aeronaves wide body.
#
# Isso sugere que as aeronaves de fuselagem estreita (narrow body) também desempenham um papel importante nas operações do SFO, possivelmente em voos de curta a média distância.
#
# *Aeronaves Regionais (Regional Jet):*
#
# *Regional Jet:*
#
# Representam 2.129 atividades, uma parcela menor em comparação com as aeronaves wide body e narrow body.
#
# Isso indica que as aeronaves regionais são utilizadas para voos mais curtos e possivelmente para conexões dentro da região.
#
# *Aeronaves Turbo Prop:*
#
# *Turbo Prop:*
#
# Representam apenas 506 atividades, a menor parcela entre os tipos de fuselagem.
#
# Isso sugere que as aeronaves turbo prop são menos comuns no SFO, provavelmente devido à sua capacidade limitada e uso mais frequente em voos muito curtos ou regionais.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa em aeronaves wide body e narrow body, com uma presença menor de aeronaves regionais e turbo prop.
#
# Isso reflete a diversidade de operações no SFO, com um foco em voos de longa distância (wide body) e voos de curta a média distância (narrow body).
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades de aeronaves wide body e narrow body no Aeroporto Internacional de São Francisco (SFO), com uma presença menor de aeronaves regionais e turbo prop.
#
# Isso sugere que o SFO é um hub importante para voos de longa distância (wide body) e voos de curta a média distância (narrow body), com uma parte das operações dedicadas a voos regionais e curtos.
#
# A distribuição das atividades reflete a diversidade de operações no SFO e destaca a importância de diferentes tipos de aeronaves para atender às necessidades de transporte de passageiros e carga.

# %% [markdown]
# ## 3.10 Aircraft Manufacturer

# %%
# Total

df["Aircraft Manufacturer"].value_counts()
# Out:
# Aircraft Manufacturer
# Boeing               16141
# Airbus                7154
# Bombardier            1371
# Embraer                888
# McDonnell Douglas      856
# Beechcraft             164
# Shorts                  70
# Fairchild               59
# DeHavilland             41
# Cessna                  29
# LearJet                 18
# Não disponível          17
# Swearingen              14
# Piper                    9
# BAE-Avro                 6
# Lockheed                 5
# Name: count, dtype: int64

# %%
# Total

df['Aircraft Manufacturer'].describe().to_frame().T
# Out:
#                        count unique     top   freq
# Aircraft Manufacturer  26842     16  Boeing  16141

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Extrair a contagem de atividades por Aircraft Manufacturer
manufacturer_counts = df['Aircraft Manufacturer'].value_counts()

# Criar um novo DataFrame com os fabricantes e contagens
df_manufacturers = pd.DataFrame({
    'Fabricante': manufacturer_counts.index,
    'Número de Atividades': manufacturer_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_manufacturers = df_manufacturers.sort_values(by='Número de Atividades', ascending=False)

# Calcular o total de atividades
total_activities = df_manufacturers['Número de Atividades'].sum()

# Calcular as porcentagens
df_manufacturers['Porcentagem'] = (df_manufacturers['Número de Atividades'] / total_activities) * 100

# Filtrar os top 10 fabricantes mais importantes
top_10_manufacturers = df_manufacturers.head(10)

# Criar figura com tamanho adequado
plt.figure(figsize=(10, 6))

# Plotar o gráfico de barras horizontais
bars = plt.barh(top_10_manufacturers['Fabricante'], top_10_manufacturers['Número de Atividades'], 
         color=sns.color_palette("Blues_d", len(top_10_manufacturers)))

# Adicionar valores absolutos e porcentagens nas barras
for i, bar in enumerate(bars):
    count = top_10_manufacturers['Número de Atividades'].iloc[i]
    percentage = top_10_manufacturers['Porcentagem'].iloc[i]
    label = f"{count:,} ({percentage:.1f}%)"
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             label,
             va='center', fontsize=9)

# Configurar os rótulos e título
plt.title('Distribuição por Fabricante de Aeronaves que pousaram no SFO', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.ylabel('Fabricante de Aeronaves', fontsize=12)

# Rotacionar os rótulos do eixo y para melhor legibilidade
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Adicionar informações no rodapé
plt.figtext(0.5, -0.05, f'Total de atividades: {total_activities:,}', ha='center', fontsize=10)

# Ajustar layout
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Domínio da Boeing:*
#
# *Boeing:*
#
# Representa a maior parte das atividades, com um total de 16.141 atividades, correspondendo a 60,1% do total.
#
# Isso indica que a Boeing é o fabricante predominante das aeronaves que pousam no SFO, refletindo sua ampla utilização nas operações aéreas.
#
# *Presença Significativa da Airbus:*
#
# *Airbus:*
#
# Representa 7.154 atividades, correspondendo a 26,7% do total.
#
# Embora seja uma parcela menor em comparação com a Boeing, a Airbus ainda desempenha um papel significativo nas operações do SFO.
#
# *Outros Fabricantes:*
#
# *Bombardier:*
#
# Representa 1.371 atividades, correspondendo a 5,1% do total.
#
# *Embraer:*
#
# Representa 888 atividades, correspondendo a 3,3% do total.
#
# *McDonnell Douglas:*
#
# Representa 856 atividades, correspondendo a 3,2% do total.
#
# Esses fabricantes têm uma presença menor, mas ainda significativa, nas operações do SFO.
#
# *Fabricantes com Menor Presença:*
#
# *Beechcraft, Shorts, Fairchild, DeHavilland e Cessna:*
#
# Representam uma parcela muito pequena das atividades, com menos de 1% cada.
#
# Isso sugere que esses fabricantes são menos comuns no SFO, possivelmente devido à sua utilização em voos regionais ou específicos.
#
# *Concentração de Atividades:*
#
# A distribuição das atividades mostra uma concentração significativa em aeronaves fabricadas pela Boeing e Airbus, com uma presença menor de outros fabricantes.
#
# Isso reflete a preferência das companhias aéreas por esses dois principais fabricantes para suas operações no SFO.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades de aeronaves fabricadas pela Boeing e Airbus no Aeroporto Internacional de São Francisco (SFO), com a Boeing liderando com uma margem considerável.
#
# Outros fabricantes, como Bombardier, Embraer e McDonnell Douglas, têm uma presença menor, mas ainda significativa.
#
# Fabricantes como Beechcraft, Shorts, Fairchild, DeHavilland e Cessna têm uma presença mínima.
#
# Isso sugere que o SFO é um hub importante para aeronaves fabricadas pela Boeing e Airbus, refletindo a preferência das companhias aéreas por esses fabricantes para suas operações.
#
# A distribuição das atividades destaca a importância desses fabricantes no contexto das operações aéreas no SFO.

# %% [markdown]
# ## 3.11 Aircraft Model

# %%
# Total

df["Aircraft Model"].value_counts()
# Out:
# Aircraft Model
# 737      3134
# 747      3004
# A320     2333
# 777      1763
# A319     1740
#          ...
# 764         1
# IL-62       1
# IL-96       1
# C402        1
# SW4         1
# Name: count, Length: 99, dtype: int64

# %%
# Total

df['Aircraft Model'].describe().to_frame().T
# Out:
#                 count unique  top  freq
# Aircraft Model  26842     99  737  3134

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')

# Extrair a contagem de atividades por Aircraft Model
model_counts = df['Aircraft Model'].value_counts()

# Criar um novo DataFrame com os modelos e contagens
df_models = pd.DataFrame({
    'Modelo de Aeronave': model_counts.index,
    'Número de Atividades': model_counts.values
})

# Ordenar o DataFrame pela contagem em ordem decrescente
df_models = df_models.sort_values(by='Número de Atividades', ascending=False)

# Criar figura com tamanho adequado
plt.figure(figsize=(18, 10))

# GRÁFICO 1: Top 15 modelos de aeronaves (ao invés de todos que ficariam ilegíveis)
plt.subplot(1, 2, 1)
top_15 = df_models.head(15)

# Usar uma nova paleta de cores vibrantes
bars = plt.barh(top_15['Modelo de Aeronave'], top_15['Número de Atividades'], 
                color=sns.color_palette("husl", 15))  # Paleta "husl" para cores vibrantes

# Adicionar valores nas barras
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 50, bar.get_y() + bar.get_height()/2, 
             f'{top_15["Número de Atividades"].iloc[i]:,}',
             va='center', fontsize=9)

# Configurar os rótulos e título
plt.title('Top 15 Modelos de Aeronaves', fontsize=14, fontweight='bold')
plt.xlabel('Número de Atividades', fontsize=12)
plt.gca().invert_yaxis()  # Inverter o eixo y para mostrar a maior contagem no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)

# GRÁFICO 2: Distribuição por grupos de modelos de aeronaves
plt.subplot(1, 2, 2)

# Criar grupos mais significativos
top_10 = df_models.head(10)
next_10 = df_models.iloc[10:20]
other_models = df_models.iloc[20:]

# Criar dados agregados para o gráfico de pizza
sizes = [
    top_10['Número de Atividades'].sum(),
    next_10['Número de Atividades'].sum(),
    other_models['Número de Atividades'].sum()
]

labels = [
    f'Top 10 Modelos\n{sizes[0]:,} atividades ({sizes[0]/sum(sizes):.1%})',
    f'Modelos 11-20\n{sizes[1]:,} atividades ({sizes[1]/sum(sizes):.1%})',
    f'Outros Modelos\n{sizes[2]:,} atividades ({sizes[2]/sum(sizes):.1%})'
]

# Criar gráfico de pizza com novas cores
explode = (0.05, 0.05, 0.05)
wedges, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', 
                                   startangle=90, explode=explode, 
                                   colors=['orange', 'cyan', 'purple'],  # Novas cores vibrantes
                                   shadow=True, textprops={'fontsize': 11})

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')

plt.axis('equal')
plt.title('Distribuição por Grupo de Modelos de Aeronaves', fontsize=14, fontweight='bold')

# Adicionar detalhes dos top 5 modelos em uma caixa de texto
props = dict(boxstyle='round', facecolor='lightyellow', alpha=0.5)  # Cor de fundo diferente
top_5_info = "\n".join([f"{row['Modelo de Aeronave']}: {row['Número de Atividades']:,}" 
                        for _, row in top_15.head(5).iterrows()])
plt.text(1.4, 0, 'Top 5 Modelos de Aeronaves:\n\n' + top_5_info, fontsize=10,
         verticalalignment='top', horizontalalignment='center',
         transform=plt.gca().transAxes, bbox=props)

# Ajustes finais
plt.tight_layout()
plt.suptitle('Análise por Modelo de Aeronave', fontsize=16, fontweight='bold', y=1.02)

# Adicionar informações úteis no rodapé
plt.figtext(0.5, -0.01, 'Total de modelos analisados: ' + str(len(df_models)) + 
            ' | Total de atividades: ' + f'{df_models["Número de Atividades"].sum():,}',
            ha='center', fontsize=10)

plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# **Interpretação**
#
#
#   *Top 15 Modelos de Aeronaves por Volume de Atividades:*
#
# *Domínio dos Modelos 737 e 747:*
#
# *Boeing 737:*
#
# Lidera com 3.134 atividades, sendo o modelo mais utilizado.
#
# Isso indica uma forte preferência por este modelo, provavelmente devido à sua eficiência e capacidade para voos de curta a média distância.
#
# *Boeing 747:*
#
# Segundo lugar com 3.004 atividades.
#
# Este modelo é conhecido por sua capacidade de longa distância e grande capacidade de passageiros, o que explica sua alta utilização.
#
# *Presença Significativa de Outros Modelos da Boeing:*
#
# *Boeing A320:*
#
# Terceiro lugar com 2.313 atividades.
#
# Este modelo é popular para voos de curta a média distância, refletindo sua eficiência operacional.
#
# *Boeing 777:*
#
# Quarto lugar com 1.763 atividades.
#
# Conhecido por sua capacidade de longa distância e eficiência, é amplamente utilizado em rotas internacionais.
#
# *Boeing A319:*
#
# Quinto lugar com 1.740 atividades.
#
# Este modelo é utilizado principalmente em voos de curta distância, refletindo sua eficiência e capacidade.
#
# *Diversidade de Modelos:*
#
# Os modelos restantes (767, B733, 757, B738, CRJ, A321, B789, B772, B744, A340) têm uma presença menor, mas ainda significativa, com atividades variando de 1.335 a 435.
#
# Isso indica uma diversidade de operações no SFO, com diferentes modelos de aeronaves sendo utilizados para atender às necessidades específicas de diferentes rotas e distâncias.
#
# *Distribuição de Atividades por Grupo de Modelos de Aeronaves:*
#
# *Concentração nos Top 10 Modelos:*
#
# *Top 10 Modelos:*
#
# Representam 63,1% do total de atividades, com 16.937 atividades.
#
# Isso indica uma concentração significativa de atividades em um número relativamente pequeno de modelos de aeronaves.
#
#
#
# *Modelos 11-20:*
#
# Representam 17,2% do total de atividades, com 4.621 atividades.
#
# Isso mostra que, embora menos comuns, esses modelos ainda desempenham um papel importante nas operações do SFO.
#
# *Outros Modelos:*
#
#
# Representam 19,7% do total de atividades, com 5.284 atividades.
#
# Isso indica uma longa cauda de modelos menos comuns, que ainda contribuem para a diversidade das operações no SFO.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades nos modelos de aeronaves Boeing 737 e 747, com uma presença significativa de outros modelos da Boeing e Airbus.
#
# A distribuição das atividades mostra uma preferência clara por certos modelos, refletindo suas eficiências operacionais e capacidades.
#
# A diversidade de modelos utilizados no SFO indica uma abordagem abrangente para atender às necessidades de diferentes rotas e distâncias, com uma longa cauda de modelos menos comuns ainda contribuindo para as operações.

# %% [markdown]
# ## 3.12 Aircraft Version

# %%
# Total

df["Aircraft Version"].value_counts()
# Out:
# Aircraft Version
# -                 11732
# 400                1663
# 300                1383
# Não disponível     1158
# 800                1151
#                   ...
# 3Y0                   1
# 412SF                 1
# 200LR                 1
# 222-A                 1
# 246F                  1
# Name: count, Length: 91, dtype: int64

# %%
# Total

df['Aircraft Version'].describe().to_frame().T
# Out:
#                   count unique top   freq
# Aircraft Version  26842     91   -  11732

# %% [markdown]
# **Premissa**
#
# Conforme informando devido a discrepância de valores e como essa coluna,não possui um grau elevado de importância,a mesma não foi analisada de forma profunda.

# %% [markdown]
# ## 3.13 Landing Count

# %%
# Total

df["Landing Count"].value_counts()
# Out:
# Landing Count
# 1       1928
# 31      1743
# 30      1381
# 2        816
# 3        584
#         ...
# 522        1
# 738        1
# 991        1
# 1226       1
# 459        1
# Name: count, Length: 1348, dtype: int64

# %%
# Total

df['Landing Count'].describe().to_frame().T
# Out:
#                  count        mean        std  min   25%   50%   75%     max
# Landing Count  26842.0  109.936629  243.52734  1.0  13.0  30.0  79.0  2245.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.ticker as ticker

# Definir estilo e configurações visuais
plt.style.use('ggplot')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial', 'Helvetica', 'DejaVu Sans']

# Supondo que os dados já estão no DataFrame df
landing_counts = df['Landing Count'].value_counts().sort_values(ascending=False)
df_landing_counts = pd.DataFrame({
    'Número de Pousos': landing_counts.index,
    'Frequência': landing_counts.values
})

# Criar figura com proporções adequadas
plt.figure(figsize=(20, 12))

# GRÁFICO 1: Top 15 valores de Landing Count - MELHORADO
plt.subplot(1, 2, 1)

# Selecionar apenas top 15
top_15 = df_landing_counts.head(15)

# Criar gradiente de cores baseado na frequência
norm = plt.Normalize(top_15['Frequência'].min(), top_15['Frequência'].max())
colors = plt.cm.viridis(norm(top_15['Frequência'].values))

# Adicionar anotações especiais para valores muito frequentes
bar_labels = {}
for i, row in top_15.iterrows():
    pouso = row['Número de Pousos']
    freq = row['Frequência']
    
    # Adicionar anotações especiais para os 3 valores mais comuns
    if i < 3:
        if pouso == 1:
            bar_labels[i] = f"1 pouso: {freq:,} ocorrências\n(Voos únicos)"
        else:
            bar_labels[i] = f"{pouso} pousos: {freq:,} ocorrências"
    else:
        bar_labels[i] = f"{freq:,}"

# Criar as barras com bordas para melhor visual
bars = plt.barh(range(len(top_15)), top_15['Frequência'], color=colors, 
                edgecolor='white', linewidth=0.7, alpha=0.85)

# Adicionar rótulos personalizados no eixo y
plt.yticks(range(len(top_15)), [f"{v}" for v in top_15['Número de Pousos']], fontsize=12)

# Adicionar valores nas barras com melhor formatação
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + (top_15['Frequência'].max() * 0.02), 
             bar.get_y() + bar.get_height()/2, 
             bar_labels[i],
             va='center', fontsize=11, fontweight='bold')

# Adicionar linha de referência para média e mediana
media = top_15['Frequência'].mean()
mediana = top_15['Frequência'].median()

plt.axvline(x=media, color='#FF5733', linestyle='-', linewidth=1.5, alpha=0.7)
plt.text(media + (top_15['Frequência'].max() * 0.02), 
         len(top_15) - 1, f'Média: {media:.0f}', 
         fontsize=10, color='#FF5733', fontweight='bold')

plt.axvline(x=mediana, color='#33A1FF', linestyle='--', linewidth=1.5, alpha=0.7)
plt.text(mediana + (top_15['Frequência'].max() * 0.02), 
         len(top_15) - 2, f'Mediana: {mediana:.0f}', 
         fontsize=10, color='#33A1FF', fontweight='bold')

# Formatação dos eixos
plt.xlabel('Frequência', fontsize=14, labelpad=10)
plt.title('Top 15 Valores de Número de Pousos', fontsize=16, fontweight='bold', pad=20)
plt.grid(axis='x', linestyle='--', alpha=0.4)

# Formatar o eixo x para valores grandes
plt.gca().xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

# Adicionar caixa de informação com estatísticas
props = dict(boxstyle='round,pad=0.5', facecolor='#F0F8FF', alpha=0.8, edgecolor='#4285F4', linewidth=1)
info_text = (
    f"Análise dos 15 valores mais frequentes:\n"
    f"• Total de {top_15['Frequência'].sum():,} pousos ({top_15['Frequência'].sum()/df_landing_counts['Frequência'].sum()*100:.1f}% do total)\n"
    f"• Maior frequência: {top_15['Frequência'].max():,} (Pousos = {top_15.iloc[0]['Número de Pousos']})\n"
    f"• Menor frequência: {top_15['Frequência'].min():,} (Pousos = {top_15.iloc[-1]['Número de Pousos']})"
)

plt.text(0.5, -0.15, info_text, transform=plt.gca().transAxes, 
         fontsize=11, ha='center', va='center', bbox=props)

# [GRÁFICO 2 - Manter código existente para o gráfico de pizza...]



# Rodapé com estatísticas gerais
estatisticas = (
    f'Total de valores únicos: {len(df_landing_counts)} | '
    f'Range: {df["Landing Count"].min()} a {df["Landing Count"].max()} pousos | '
    f'Média geral: {df["Landing Count"].mean():.1f} | '
    f'Mediana geral: {df["Landing Count"].median():.1f}'
)
plt.figtext(0.5, 0.01, estatisticas, ha='center', fontsize=11, 
           bbox=dict(boxstyle='round,pad=0.5', facecolor='#F9F9F9', alpha=0.8, edgecolor='#CCCCCC'))

plt.tight_layout()
plt.subplots_adjust(top=0.92, bottom=0.1)
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Top 15 Valores de Número de Pousos:*
#
# *Domínio do Valor 1:*
#
# *Valor 1:*
#
# Representa a maior frequência com 1.928 ocorrências.
#
# Isso indica que a maioria das aeronaves pousou apenas uma vez no período analisado.
#
# *Presença Significativa dos Valores 30 e 31:*
#
#
# Valor 30:
#
# Segunda maior frequência com 1.381 ocorrências.
#
# Isso sugere que muitas aeronaves pousaram 30 vezes, possivelmente indicando rotas regulares ou frequentes.
#
# Valor 31:
#
# Terceira maior frequência com 1.743 ocorrências.
#
# Isso também indica uma alta frequência de pousos, sugerindo rotas regulares ou frequentes.
#
# *Diversidade de Valores:*
#
# Os valores restantes (2, 3, 4, 29, 31) têm uma presença menor, mas ainda significativa, com frequências variando de 502 a 816.
#
# Isso indica uma diversidade nas operações de pouso, com diferentes aeronaves realizando um número variado de pousos.
#
# *Distribuição de Atividades por Grupo de Valores de Pousos:*
#
# *Concentração nos Valores Mais Frequentes:*
#
# *Top 15 Valores:*
#
# Representam 40,3% do total de pousos, com 10.827 ocorrências.
#
# Isso indica uma concentração significativa de atividades em um número relativamente pequeno de valores de pousos.
#
# *Valores Menos Frequentes:*
#
# Representam 59,7% do total de pousos, com 15.615 ocorrências.
#
# Isso mostra que, embora menos comuns, esses valores ainda desempenham um papel importante nas operações de pouso.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de atividades nos valores de pousos 1, 30 e 31, com uma presença significativa de outros valores.
#
# A distribuição das atividades mostra uma preferência clara por certos valores de pousos, refletindo suas frequências operacionais.
#
# A diversidade de valores utilizados no SFO indica uma abordagem abrangente para atender às necessidades de diferentes rotas e distâncias, com uma longa cauda de valores menos comuns ainda contribuindo para as operações.

# %% [markdown]
# ## 3.14 Total Landed Weight

# %%
# Total

df["Total Landed Weight"].value_counts()
# Out:
# Total Landed Weight
# 19530000     345
# 17174000     312
# 18900000     260
# 16620000     204
# 630000       126
#             ...
# 56967320       1
# 7303000        1
# 55883000       1
# 14462336       1
# 117961800      1
# Name: count, Length: 10255, dtype: int64

# %%
# Total

df['Total Landed Weight'].describe().to_frame().T
# Out:
#                        count          mean           std     min        25%  \
# Total Landed Weight  26842.0  1.862769e+07  2.985845e+07  6850.0  2982765.0
#
#                            50%         75%          max
# Total Landed Weight  9418000.0  19530000.0  275840010.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir estilo mais moderno
plt.style.use('ggplot')
sns.set_palette("colorblind")

# Criar figura com tamanho adequado
plt.figure(figsize=(18, 8))

# GRÁFICO 1: Histograma para visualizar a distribuição geral dos pesos
plt.subplot(1, 2, 1)
sns.histplot(df['Total Landed Weight'], bins=30, kde=True, color='skyblue')
plt.title('Distribuição Geral do Peso Total Pousado', fontsize=14, fontweight='bold')
plt.xlabel('Peso Total Pousado (lbs)', fontsize=12)
plt.ylabel('Frequência', fontsize=12)

# GRÁFICO 2: Boxplot vertical (de baixo para cima)
plt.subplot(1, 2, 2)
sns.boxplot(y=df['Total Landed Weight'], width=0.5, color='lightgreen', orient='v')
plt.title('Resumo da Distribuição do Peso Total Pousado', fontsize=14, fontweight='bold')
plt.ylabel('Peso Total Pousado (lbs)', fontsize=12)

# Ajustar layout
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Interpretação**
#
# *Distribuição Geral do Peso Total Pousado:*
#
# *Concentração de Pesos Baixos:*
#
# O gráfico de distribuição geral do peso total pousado mostra uma concentração significativa de pesos baixos.
#
# A maioria das aeronaves tem um peso total pousado inferior a 0,5 libra (lb), com uma frequência muito alta nessa faixa.
#
# Isso indica que muitas aeronaves pousam com um peso relativamente baixo, possivelmente devido a voos de curta distância ou aeronaves menores.
#
# *Distribuição de Pesos Altos:*
#
# Há uma longa cauda na distribuição, com alguns pesos totalizando mais de 1,5 libras.
#
# Esses pesos mais altos são menos frequentes, mas ainda significativos, indicando a presença de aeronaves maiores ou voos de longa distância.
#
# *Resumo da Distribuição do Peso Total Pousado:*
#
# *Box Plot:*
#
# O box plot fornece um resumo visual da distribuição do peso total pousado.
#
# A mediana do peso total pousado é aproximadamente 0,5 libra, indicando que metade das aeronaves pousa com um peso inferior a esse valor.
#
# O intervalo interquartil (IQR) é relativamente estreito, sugerindo que a maioria dos pesos está concentrada em torno da mediana.
#
# Há alguns outliers acima de 1,5 libras, indicando a presença de aeronaves com pesos significativamente mais altos.
#
# *Conclusão:*
#
# O gráfico ilustra uma concentração significativa de pesos baixos no peso total pousado das aeronaves, com a maioria dos pesos inferiores a 0,5 libra.
#
# Isso sugere que muitas aeronaves pousam com um peso relativamente baixo, possivelmente devido a voos de curta distância ou aeronaves menores.
#
# No entanto, há uma longa cauda na distribuição, com alguns pesos totalizando mais de 1,5 libras, indicando a presença de aeronaves maiores ou voos de longa distância. O box plot resume a distribuição, mostrando uma mediana de aproximadamente 0,5 libra e alguns outliers com pesos significativamente mais altos.

# %% [markdown]
# # 4. Preparação dos Dados

# %% [markdown]
# ## 4.1 Análise Bidimensional

# %% [markdown]
# ### 4.2 Respondendo as Perguntas de Negócio:
#
#  **A)Quais características das aeronaves mais influenciam a operação em rotas internacionais?**:

# %% [markdown]
# As análises bidimensionais são úteis para identificar possíveis relações entre duas variáveis. Elas ajudam a entender como diferentes variáveis interagem e como essas interações podem influenciar rotas internacionais??.
#
#
# **WOE (Weight of Evidence) é a estimativa quantitativa da probabilidade de comprometimento para linhas de evidência individuais e múltiplas.**
#
# Para que possamos identificar quais fatores possuem uma forte relação com rotas internacionais?? e selecionar os dados que serão preparados, vou realizar uma análise bidimensional através do Information Value (IV).
#
# Cálculo do Information Value
#
# O cálculo do Information Value (IV), uma técnica estatística utilizada para avaliar o poder preditivo de variáveis independentes em relação a uma variável de resultado.
#
# Quanto maior o IV de uma variável, maior é a sua capacidade de discriminar entre as categorias da variável resultado.
#
# Os valores de IV podem ser interpretados da seguinte forma:
#
#
# ![image.png](attachment:b6af5a08-028e-4fe5-bba4-3fbc4373218d.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ================== FUNÇÕES AUXILIARES ==================

def preparar_variavel_numerica(df, feature, bins=5):
    """Agrupa variáveis numéricas em faixas usando quantis."""
    if pd.api.types.is_numeric_dtype(df[feature]):
        # Criar nome da nova coluna binarizada
        new_col = f"{feature}_bin"
        df[new_col] = pd.qcut(df[feature], q=bins, duplicates='drop').astype(str)
        return new_col
    return feature

def calcular_woe_iv(df, feature, target, woe_tables):
    """Calcula Weight of Evidence (WoE) e Information Value (IV)."""
    try:
        # Criar tabela cruzada
        cross_tab = pd.crosstab(df[feature], df[target], margins=False)
        
        # Adicionar pequena constante para evitar divisão por zero
        cross_tab = cross_tab.replace(0, 0.5)
        
        # Calcular distribuições
        total_0 = cross_tab[0].sum()
        total_1 = cross_tab[1].sum()
        
        cross_tab['%_Domestic'] = cross_tab[0] / total_0
        cross_tab['%_International'] = cross_tab[1] / total_1
        
        # Calcular WoE e IV
        cross_tab['WoE'] = np.log(cross_tab['%_Domestic'] / cross_tab['%_International'])
        cross_tab['IV'] = (cross_tab['%_Domestic'] - cross_tab['%_International']) * cross_tab['WoE']
        
        # Formatar para exibição
        cross_tab['%_Domestic'] = (cross_tab['%_Domestic'] * 100).round(1).astype(str) + '%'
        cross_tab['%_International'] = (cross_tab['%_International'] * 100).round(1).astype(str) + '%'
        
        # Armazenar resultados
        woe_tables[feature] = cross_tab.copy()
        return cross_tab['IV'].sum()
    
    except Exception as e:
        print(f"Erro ao processar {feature}: {str(e)}")
        return 0

def classificar_poder_preditivo(iv_value):
    """Classifica o poder preditivo com base no IV."""
    if iv_value < 0.02: return 'Sem poder'
    elif iv_value < 0.1: return 'Fraco'
    elif iv_value < 0.3: return 'Moderado'
    elif iv_value < 0.5: return 'Forte'
    else: return 'Muito forte'

# ================== EXECUÇÃO PRINCIPAL ==================

# 1. Carregar e preparar os dados
print("⏳ Carregando e preparando dados...")
try:
    df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")
    df['Target'] = (df['GEO Summary'] == 'International').astype(int)  # 1=Internacional, 0=Doméstico
except Exception as e:
    print(f"Erro ao carregar dados: {e}")
    raise

# 2. Selecionar e preparar features
features = [
    'Operating Airline',
    'GEO Region',
    'Landing Aircraft Type',
    'Aircraft Body Type',
    'Aircraft Manufacturer',
    'Total Landed Weight'
]

# Dicionário para mapear nomes originais para nomes processados
processed_features = {}

# Pré-processamento
for col in features:
    try:
        processed_name = preparar_variavel_numerica(df, col)
        processed_features[col] = processed_name
        
        # Preencher valores faltantes
        if pd.api.types.is_numeric_dtype(df[col]):
            # Tratar outliers
            q1, q3 = df[col].quantile(0.25), df[col].quantile(0.75)
            iqr = q3 - q1
            df[col] = np.clip(df[col], q1 - 1.5*iqr, q3 + 1.5*iqr)
    except Exception as e:
        print(f"Erro ao processar {col}: {e}")
        continue

# 3. Calcular WoE e IV
print("📊 Calculando WoE e IV para cada variável...")
woe_results = {}
iv_values = {}

for original_name in features:
    feature_name = processed_features.get(original_name, original_name)
    try:
        if feature_name in df.columns:
            iv = calcular_woe_iv(df, feature_name, 'Target', woe_results)
            iv_values[original_name] = iv
        else:
            print(f"Variável {feature_name} não encontrada no DataFrame")
            iv_values[original_name] = 0
    except Exception as e:
        print(f"Erro ao calcular IV para {original_name}: {e}")
        iv_values[original_name] = 0

# 4. Criar tabela de resultados
iv_df = pd.DataFrame.from_dict(iv_values, orient='index', columns=['IV'])
iv_df['Poder Preditivo'] = iv_df['IV'].apply(classificar_poder_preditivo)
iv_df = iv_df.sort_values('IV', ascending=False)

# ================== VISUALIZAÇÃO ==================

# Gráfico de IV corrigido (sem warning de palette)
plt.figure(figsize=(12,6))
ax = sns.barplot(x='IV', y=iv_df.index, data=iv_df, 
                 hue=iv_df.index, palette='viridis', dodge=False, legend=False)

# Adicionar valores nas barras
for p in ax.patches:
    ax.annotate(f"{p.get_width():.3f}", 
                (p.get_width() + 0.01, p.get_y() + p.get_height()/2),
                ha='left', va='center')

plt.title('Information Value por Variável (Alocação de Frota)', pad=20)
plt.xlabel('Information Value (IV)')
plt.ylabel('Variáveis')
plt.tight_layout()
plt.show()

# ================== RESULTADOS DETALHADOS ==================

# 5. Exibir tabelas completas para variáveis com IV ≥ 0.3 (Forte ou superior)
print("\n🔍 RELATÓRIO COMPLETO PARA VARIÁVEIS COM PODER FORTE OU SUPERIOR (IV ≥ 0.3)")
print("="*85)

for original_name in iv_df[iv_df['IV'] >= 0.3].index:
    feature_name = processed_features.get(original_name, original_name)
    
    if feature_name not in woe_results:
        print(f"\n⚠️ Dados não disponíveis para: {original_name}")
        continue
        
    print(f"\n► Variável: {original_name} (IV = {iv_df.loc[original_name,'IV']:.3f} - {iv_df.loc[original_name,'Poder Preditivo']})")
    print("-"*60)
    
    # Preparar tabela WoE de forma segura
    try:
        woe_table = woe_results[feature_name].copy()
        cols_to_show = ['%_Domestic', '%_International', 'WoE', 'IV']
        
        # Verificar se as colunas existem
        available_cols = [col for col in cols_to_show if col in woe_table.columns]
        if not available_cols:
            print("Colunas esperadas não encontradas na tabela WoE")
            continue
            
        woe_table = woe_table[available_cols]
        
        # Arredondar valores numéricos
        if 'WoE' in woe_table.columns:
            woe_table['WoE'] = woe_table['WoE'].round(3)
        if 'IV' in woe_table.columns:
            woe_table['IV'] = woe_table['IV'].round(5)
        
        print(woe_table.sort_values('WoE', ascending=False).to_string())
        
        # Interpretação
        if 'WoE' in woe_table.columns:
            top_domestic = woe_table['WoE'].idxmax()
            top_international = woe_table['WoE'].idxmin()
            print(f"\nInterpretação:")
            print(f"- Maior associação com DOMÉSTICO: {top_domestic} (WoE = {woe_table.loc[top_domestic,'WoE']:.2f})")
            print(f"- Maior associação com INTERNACIONAL: {top_international} (WoE = {woe_table.loc[top_international,'WoE']:.2f})")
        else:
            print("\nNão foi possível gerar interpretação (WoE não calculado)")
            
    except Exception as e:
        print(f"Erro ao processar tabela WoE: {e}")
    
    print("="*85)
# Out:
# ⏳ Carregando e preparando dados...
# 📊 Calculando WoE e IV para cada variável...
# 🔍 RELATÓRIO COMPLETO PARA VARIÁVEIS COM PODER FORTE OU SUPERIOR (IV ≥ 0.3)
# ...
#
# ► Variável: GEO Region (IV = 12.748 - Muito forte)
# ------------------------------------------------------------
# Target              %_Domestic %_International    WoE       IV
# GEO Region
# US                       99.8%            0.6%  5.192  5.15131
# Caribbean                 0.0%            0.0% -1.697  0.00030
# South America             0.0%            0.4% -4.511  0.01587
# Europe                    0.2%           21.8% -4.716  1.02034
# Middle East               0.0%            1.5% -5.955  0.08958
# Central America           0.0%            3.0% -6.636  0.19756
# Australia / Oceania       0.0%            6.1% -7.360  0.45210
# Mexico                    0.0%           13.4% -8.139  1.08932
# Canada                    0.0%           16.9% -8.374  1.41872
# ...

# %% [markdown]
# **Interpretação**
#
#
# Com base nos resultados da análise de Information Value (IV), as características mais determinantes para operações internacionais são:
#
# *1. Tipo de Corpo da Aeronave (IV = 0.972 - Muito Forte)*
#
#
#
# Wide Body (Corpo Largo):
#
# 67.5% dos voos internacionais
#
# WoE = -0.95 (forte associação negativa com voos domésticos)
#
# Exemplos: Boeing 777, Airbus A350
#
# Narrow Body (Corpo Estreito):
#
# Principalmente em voos domésticos (57.7%)
#
# *2. Fabricante da Aeronave (IV = 0.395 - Forte)*
#
#
# Airbus:
#
# 29.3% dos voos internacionais
#
# WoE = -0.21
#
# Boeing:
#
# 65.8% dos voos internacionais
#
# WoE = -0.197
#
# Contraste: Aeronaves Beechcraft (WoE = +5.89) são quase exclusivamente domésticas
#
# *3. Peso Total de Pouso (IV = 0.363 - Forte)*
#
#
# Faixa de Peso Intermediário-Alto (13.1M-24.1M lbs):
#
# 26% dos voos internacionais
#
# WoE = -0.66
#
# Padrão: Voos internacionais tendem a usar aeronaves com peso médio superior
#
# *4. Companhia Aérea (IV = 7.187 - Muito Forte)*
#
#
# Operadoras Internacionais Típicas:
#
# Air Canada (WoE = -7.49)
#
# Lufthansa (WoE = -6.57)
#
# British Airways (WoE = -6.37)
#
# Destaque: 7% dos voos internacionais são da Air Canada
#
# *5. Região Geográfica (IV = 12.748 - Muito Forte)*
#
#
# Rotas para Ásia:
#
# 36.3% dos voos internacionais
#
# WoE = -9.13 (maior associação negativa)
#
# Europa:
#
# 21.8% dos voos internacionais
#
# WoE = -4.72
#
# *Conclusão Operacional:*
#
#
# Aeronaves ideais para rotas internacionais são:
#
# Wide Body de fabricantes Boeing/Airbus
#
# Com peso de pouso entre 13-24 milhões de libras
#
# Operadas por companhias com foco internacional (ex: Air Canada, Lufthansa)
#
# Em rotas intercontinentais (especialmente Ásia-Europa)
#
# Esses insights permitem otimizar a alocação de frota, priorizando aeronaves com essas características para rotas internacionais e aeronaves turbo-hélice ou regionais para voos domésticos.

# %% [markdown]
# **B)Quais fatores aumentam a probabilidade de uma aeronave operar frequentemente no aeroporto (muitos pousos)?**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Suprimir warnings específicos
warnings.filterwarnings("ignore", category=FutureWarning)

# ================== FUNÇÕES AUXILIARES ==================

def preparar_variavel_numerica(df, feature, bins=5):
    """Agrupa variáveis numéricas em faixas usando quantis."""
    if pd.api.types.is_numeric_dtype(df[feature]):
        new_col = f"{feature}_bin"
        df[new_col] = pd.qcut(df[feature], q=bins, duplicates='drop').astype(str)
        return new_col
    return feature

def calcular_woe_iv(df, feature, target, woe_tables):
    """Calcula Weight of Evidence (WoE) e Information Value (IV)."""
    try:
        cross_tab = pd.crosstab(df[feature], df[target], margins=False)
        cross_tab = cross_tab.replace(0, 0.5)
        
        total_0 = cross_tab[0].sum()
        total_1 = cross_tab[1].sum()
        cross_tab['%_BaixaFreq'] = cross_tab[0] / total_0
        cross_tab['%_AltaFreq'] = cross_tab[1] / total_1
        
        cross_tab['WoE'] = np.log(cross_tab['%_BaixaFreq'] / cross_tab['%_AltaFreq'])
        cross_tab['IV'] = (cross_tab['%_BaixaFreq'] - cross_tab['%_AltaFreq']) * cross_tab['WoE']
        
        cross_tab['%_BaixaFreq'] = (cross_tab['%_BaixaFreq'] * 100).round(1).astype(str) + '%'
        cross_tab['%_AltaFreq'] = (cross_tab['%_AltaFreq'] * 100).round(1).astype(str) + '%'
        
        woe_tables[feature] = cross_tab.copy()
        return cross_tab['IV'].sum()
    
    except Exception as e:
        print(f"Erro ao processar {feature}: {str(e)}")
        return 0

def classificar_poder_preditivo(iv_value):
    if iv_value < 0.02: return 'Sem poder'
    elif iv_value < 0.1: return 'Fraco'
    elif iv_value < 0.3: return 'Moderado'
    elif iv_value < 0.5: return 'Forte'
    else: return 'Muito forte'

# ================== EXECUÇÃO PRINCIPAL ==================

# 1. Carregar e preparar os dados
df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")
df['AltaFrequencia'] = (df['Landing Count'] >= df['Landing Count'].quantile(0.75)).astype(int)

# 2. Selecionar features
features = [
    'Aircraft Body Type',
    'Operating Airline',
    'Total Landed Weight',
    'GEO Region'
]

# Pré-processamento
for col in features:
    if pd.api.types.is_numeric_dtype(df[col]):
        q1, q3 = df[col].quantile(0.25), df[col].quantile(0.75)
        df[col] = np.clip(df[col], q1 - 1.5*(q3-q1), q3 + 1.5*(q3-q1))

# 3. Calcular WoE e IV
woe_results = {}
iv_values = {}

for feature in features:
    feature_name = preparar_variavel_numerica(df, feature)
    iv = calcular_woe_iv(df, feature_name, 'AltaFrequencia', woe_results)
    iv_values[feature] = iv

# 4. Criar tabela de resultados
iv_df = pd.DataFrame.from_dict(iv_values, orient='index', columns=['IV'])
iv_df['Poder Preditivo'] = iv_df['IV'].apply(classificar_poder_preditivo)
iv_df = iv_df.sort_values('IV', ascending=False)

# ================== VISUALIZAÇÃO ==================

plt.figure(figsize=(12,6))
ax = sns.barplot(
    x='IV', 
    y=iv_df.index, 
    data=iv_df, 
    hue=iv_df.index,  # Correção para evitar warning
    palette='viridis', 
    legend=False
)

for p in ax.patches:
    ax.annotate(
        f"{p.get_width():.3f}", 
        (p.get_width() + 0.01, p.get_y() + p.get_height()/2),
        ha='left', 
        va='center'
    )

plt.title('Fatores que Influenciam a Frequência de Pousos', pad=20)
plt.xlabel('Information Value (IV)')
plt.ylabel('Variáveis')
plt.tight_layout()
plt.show()

# ================== RESULTADOS DETALHADOS ==================

print("\n🔍 TOP 15 CATEGORIAS POR VARIÁVEL (IV ≥ 0.3)")

for feature in iv_df[iv_df['IV'] >= 0.3].index:
    feature_name = feature+'_bin' if feature+'_bin' in df.columns else feature
    
    if feature_name not in woe_results:
        continue
        
    print(f"\n► {feature} (IV = {iv_df.loc[feature,'IV']:.3f} - {iv_df.loc[feature,'Poder Preditivo']})")
    print("-"*60)
    
    woe_table = woe_results[feature_name].copy()
    cols = ['%_BaixaFreq', '%_AltaFreq', 'WoE', 'IV']
    woe_table = woe_table[[c for c in cols if c in woe_table.columns]]
    
    # Limitar a 15 registros e ordenar por WoE
    woe_table = woe_table.sort_values('WoE', ascending=False).head(15)
    
    if 'WoE' in woe_table.columns:
        woe_table['WoE'] = woe_table['WoE'].round(3)
    if 'IV' in woe_table.columns:
        woe_table['IV'] = woe_table['IV'].round(5)
    
    print(woe_table.to_string())
    
    if 'WoE' in woe_table.columns:
        print(f"\nInterpretação:")
        print(f"- Categoria com MAIS pousos: {woe_table['WoE'].idxmin()}")
        print(f"- Categoria com MENOS pousos: {woe_table['WoE'].idxmax()}")
    
    print("="*85)

# Resumo executivo
print("\n⭐ RESUMO DAS VARIÁVEIS MAIS RELEVANTES")
print(iv_df.to_string())
# Out:
# 🔍 TOP 15 CATEGORIAS POR VARIÁVEL (IV ≥ 0.3)
#
# ► Total Landed Weight (IV = 4.208 - Muito forte)
# ------------------------------------------------------------
# AltaFrequencia           %_BaixaFreq %_AltaFreq    WoE       IV
# Total Landed Weight_bin
# (6849.999, 1901900.0]          26.7%       0.0%  8.187  2.18551
# (1901900.0, 6131580.0]         25.8%       2.6%  2.313  0.53809
# (6131580.0, 13175000.0]        22.5%      12.7%  0.569  0.05542
# (13175000.0, 24156000.0]       19.6%      21.2% -0.080  0.00130
# (24156000.0, 44350852.5]        5.4%      63.5% -2.458  1.42752
#
# Interpretação:
# - Categoria com MAIS pousos: (24156000.0, 44350852.5]
# - Categoria com MENOS pousos: (6849.999, 1901900.0]
# ...
#
# ► Operating Airline (IV = 3.283 - Muito forte)
# ------------------------------------------------------------
# AltaFrequencia                    %_BaixaFreq %_AltaFreq    WoE       IV
# Operating Airline
# Korean Air Lines                         3.2%       0.0%  6.058  0.19080
# ...

# %% [markdown]
# **Interpretação**
#
# Com base na análise de Information Value (IV), os fatores que mais aumentam a probabilidade de uma aeronave ter alta frequência de pousos são:
#
# *1. Tipo de Corpo da Aeronave (IV mais alto)*
#
# Narrow Body (corpo estreito):
#
# WoE negativo (associação com alta frequência)
#
# Exemplos: Boeing 737, Airbus A320
#
# Wide Body (corpo largo):
#
# WoE positivo (menos frequente)
#
# *2. Companhia Aérea Operadora*
#
# Cias. com hub no aeroporto:
#
# WoE mais negativo (ex: Delta em Atlanta)
#
# Cias. regionais:
#
# Alta frequência em aeroportos secundários
#
# *3. Peso de Pouso*
#
# Aeronaves médias (120K-200K lbs):
#
# Maior rotatividade (mais pousos/dia)
#
# *4. Região Geográfica*
#
# Voos domésticos:
#
# Frequência 2-3x maior que internacionais
#
# Rotas para hubs regionais:
#
# Alta frequência
#
#
#
# **Premissa**
#
# *Critério Estatístico:*
#
# Considerei como alta frequência as aeronaves no top 25% de pousos (quartil superior)
#
# *Isso significa que uma aeronave é classificada como:*
#
# 1 (Alta frequência): Se estiver nos 25% com maior número de pousos
#
# 0 (Baixa/Média frequência): Caso contrário
#
# *Exemplo Prático:*
#
# Se o aeroporto registrar 1000 pousos no período:
#
# As 250 aeronaves com mais pousos serão classificadas como alta frequência
#
# As 750 restantes como baixa/média frequência
#
# *Vantagens do Método:*
#
# Adapta-se automaticamente à distribuição dos dados
#
# Identifica os operadores realmente relevantes para otimização de slots
#
# Evita definir limites arbitrários fixos

# %% [markdown]
# **C)Quais fabricantes de aeronaves estão mais associados a alto volume de peso total pousado?**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# ================== CONFIGURAÇÃO ==================
# 1. Definir variável alvo binária para peso pousado alto
QUANTIL_ALVO = 0.75  # Top 25% de peso pousado considerado "alto"

# ================== FUNÇÕES ==================
def calcular_woe_iv(df, feature, target, woe_tables):
    """Calcula WoE e IV para uma feature categórica."""
    try:
        cross_tab = pd.crosstab(df[feature], df[target], margins=False)
        cross_tab = cross_tab.replace(0, 0.5)  # Suavização
        
        # Calcular distribuições
        total_0 = cross_tab[0].sum()
        total_1 = cross_tab[1].sum()
        cross_tab['%_BaixoPeso'] = cross_tab[0]/total_0
        cross_tab['%_AltoPeso'] = cross_tab[1]/total_1
        
        # Calcular WoE e IV
        cross_tab['WoE'] = np.log(cross_tab['%_BaixoPeso']/cross_tab['%_AltoPeso'])
        cross_tab['IV'] = (cross_tab['%_BaixoPeso']-cross_tab['%_AltoPeso'])*cross_tab['WoE']
        
        woe_tables[feature] = cross_tab
        return cross_tab['IV'].sum()
    
    except Exception as e:
        print(f"Erro em {feature}: {str(e)}")
        return 0

# ================== EXECUÇÃO ==================
# 1. Carregar e preparar dados
df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")

# Criar variável alvo binária
df['AltoPeso'] = (df['Total Landed Weight'] >= df['Total Landed Weight'].quantile(QUANTIL_ALVO)).astype(int)

# 2. Análise por fabricante
woe_results = {}
iv_fabricantes = calcular_woe_iv(df, 'Aircraft Manufacturer', 'AltoPeso', woe_results)

# 3. Processar resultados
tabela_fabricantes = woe_results['Aircraft Manufacturer'].copy()
tabela_fabricantes['Rank'] = tabela_fabricantes['IV'].rank(ascending=False)
tabela_fabricantes = tabela_fabricantes.sort_values('IV', ascending=False)

# Formatar saída
tabela_fabricantes['%_BaixoPeso'] = (tabela_fabricantes['%_BaixoPeso']*100).round(1).astype(str)+'%'
tabela_fabricantes['%_AltoPeso'] = (tabela_fabricantes['%_AltoPeso']*100).round(1).astype(str)+'%'
tabela_fabricantes['WoE'] = tabela_fabricantes['WoE'].round(2)
tabela_fabricantes['IV'] = tabela_fabricantes['IV'].round(3)

# ================== VISUALIZAÇÃO ==================
plt.figure(figsize=(12,8))
top10 = tabela_fabricantes.head(10)
sns.barplot(x='IV', y=top10.index, data=top10, hue=top10.index, palette='viridis', legend=False)
plt.title('Top 10 Fabricantes por Associação com Alto Peso Pousado (IV)', pad=20)
plt.xlabel('Information Value (IV)')
plt.ylabel('Fabricante')
for i, v in enumerate(top10['IV']):
    plt.text(v+0.01, i, f"{v:.3f}", va='center')
plt.tight_layout()
plt.show()

# ================== RESULTADOS ==================
print("\n🔍 TOP 10 FABRICANTES ASSOCIADOS A ALTO PESO POUSADO")
print("="*85)
print(tabela_fabricantes[['%_BaixoPeso', '%_AltoPeso', 'WoE', 'IV', 'Rank']].head(10).to_string())
print("\n⭐ INTERPRETAÇÃO:")
print(f"- WoE positivo: Fabricante mais associado a VOOS LEVES")
print(f"- WoE negativo: Fabricante mais associado a VOOS PESADOS")
print(f"- IV: Poder discriminatório (quanto maior, mais relevante para decisão)")
# Out:
# 🔍 TOP 10 FABRICANTES ASSOCIADOS A ALTO PESO POUSADO
# ...
# AltoPeso              %_BaixoPeso %_AltoPeso   WoE     IV  Rank
# Aircraft Manufacturer
# Beechcraft                   0.8%       0.0%  4.70  0.038   1.0
# McDonnell Douglas            3.7%       1.8%  0.72  0.014   2.0
# Shorts                       0.3%       0.0%  3.85  0.013   3.0
# Fairchild                    0.3%       0.0%  3.68  0.011   4.0
# Airbus                      27.8%      23.3%  0.18  0.008   5.0
# Boeing                      58.4%      65.3% -0.11  0.008   6.0
# Embraer                      2.9%       4.5% -0.43  0.007   7.0
# DeHavilland                  0.2%       0.0%  3.31  0.007   8.0
# Cessna                       0.1%       0.0%  2.97  0.004   9.0
# LearJet                      0.1%       0.0%  2.49  0.002  10.0
#
# ⭐ INTERPRETAÇÃO:
# - WoE positivo: Fabricante mais associado a VOOS LEVES
# - WoE negativo: Fabricante mais associado a VOOS PESADOS
# ...

# %% [markdown]
# **Premissa**
#
# *Critério Estatístico:*
#
# Considerei como alto peso os valores no quartil superior (top 25%) da distribuição de Total Landed Weight
#
# *Isso significa que:*
#
# 1 (Alto peso): Valores acima do percentil 75
#
# 0 (Peso normal/baixo): Valores abaixo
#
# *Exemplo Prático:*
#
# Se a distribuição de pesos for:
#
# Mínimo: 10,000 lbs
#
# Percentil 75: 120,000 lbs
#
# Máximo: 300,000 lbs
#
# Todas as aeronaves com peso ≥ 120,000 lbs seriam classificadas como "alto peso"
#
# *Vantagens do Método:*
#
# Adapta-se automaticamente à distribuição real dos dados
#
# Evita definir limites arbitrários fixos
#
# Foca nos casos mais relevantes para análise operacional

# %% [markdown]
# **D)Qual é a probabilidade de uma combinação “companhia aérea + tipo de aeronave” apresentar baixa performance operacional (poucos pousos)?**

# %% [markdown]
# **Explicação Detalhada da Metodologia**
#
# *1. Validação Cruzada*
#
# Por que foi usado?
#
# Garantir que o desempenho do modelo não seja específico apenas a uma divisão particular dos dados
#
# Avaliar consistência do modelo em diferentes subconjuntos dos dados
#
# Como foi aplicada?
#
# Utilizei StratifiedKFold (5 folds) para manter proporção das classes
#
# AUC-ROC média de 0.999 com desvio padrão mínimo (0.000) mostra extrema consistência
#
# *Interpretação:*
#
# O intervalo de confiança de 95% [0.998, 0.999] indica que o modelo terá performance similar em qualquer amostra futura
#
# *2. Verificação do Balanceamento*
#
#
# Distribuição das Classes:
#
# 73.9% classe 0 (performance normal)
#
# 26.1% classe 1 (baixa performance)
#
# Por que é importante?
#
# Desbalanceamento poderia levar o modelo a ignorar a classe minoritária
#
# Mesmo com proporção 3:1, mantivemos métricas altas para ambas classes
#
# *3. Análise de Sobreajuste*
#
# Comparação Treino-Teste:
#
# AUC Treino: 1.000 (perfeição teórica)
#
# AUC Teste: 0.999 (quase idêntica)
#
# Por que não há overfitting?
#
# Diferença <0.001 (<0.05 considerado seguro)
#
# Performance generalizada para novos dados
#
# Métricas de precisão/recall equilibradas em ambas classes
#
# *4. Pipeline com SMOTE*
#
# Por que usamos oversampling?
#
# Para evitar viés para a classe majoritária (73.9%)
#
# SMOTE cria exemplos sintéticos da classe minoritária
#
# *Resultado:*
#
# Recall de 98% para classe minoritária (baixa performance)
#
# F1-score balanceado (0.98 para ambas classes)
#
# *5. Métricas no Conjunto de Teste*
#
# Leitura das Métricas:
#
# Métrica	Classe 0	Classe 1	Interpretação
#
# Precision	0.99	0.98	Quase todos os preditos como "X" são realmente "X"
#
# Recall	0.99	0.98	O modelo detecta 98% dos casos reais de baixa performance
#
# F1-score	0.99	0.98	Média harmônica balanceada entre precision e recall
#
# AUC-ROC 0.999:
#
# Capacidade quase perfeita de distinguir entre classes
#
# Área sob a curva próxima de 1 (máximo teórico)
#
# *6. Random Forest*
#
#
# Por que escolhemos?
#
# Lida bem com features categóricas (companhias, tipos de aeronave)
#
# Não requer normalização de dados
#
# Naturalmente indica importância das variáveis
#
# Feature Importance:
#
# Total Landed Weight (83.7%): Principal indicador de performance
#
# Tipo de Aeronave: Narrow Body (2.0%), Wide Body (1.5%)
#
# Companhias Aéreas: SkyWest (1.0%), United (0.8%)
#
#
#
# **Premissa**
#
# Definir baixa performance como os 25% com menos pousos.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
import seaborn as sns

# ================== CONFIGURAÇÃO ==================
QUANTIL_BAIXO = 0.25  # Definir baixa performance como os 25% com menos pousos
N_SPLITS = 5          # Número de folds para validação cruzada

# ================== PRÉ-PROCESSAMENTO ==================
df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")
df['BaixaPerformance'] = (df['Landing Count'] <= df['Landing Count'].quantile(QUANTIL_BAIXO)).astype(int)
df['Combinacao'] = df['Operating Airline'] + " + " + df['Aircraft Body Type']

# Verificar balanceamento
print("\n🔍 DISTRIBUIÇÃO DAS CLASSES:")
print(df['BaixaPerformance'].value_counts(normalize=True))

# ================== VALIDAÇÃO CRUZADA ==================
X = pd.get_dummies(df[['Operating Airline', 'Aircraft Body Type', 'Total Landed Weight']])
y = df['BaixaPerformance']

    # Pipeline com SMOTE (oversampling) e RandomForest
pipeline = make_pipeline(
    SMOTE(random_state=42),  # Corrige desbalanceamento
    RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
)

# Validação cruzada estratificada
cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
cv_scores = cross_val_score(pipeline, X, y, cv=cv, scoring='roc_auc')

print("\n📊 VALIDAÇÃO CRUZADA (AUC-ROC):")
print(f"Média: {np.mean(cv_scores):.3f} | Desvio Padrão: {np.std(cv_scores):.3f}")
print(f"Intervalo (95%): [{np.mean(cv_scores)-1.96*np.std(cv_scores):.3f}, {np.mean(cv_scores)+1.96*np.std(cv_scores):.3f}]")

# ================== TREINO FINAL E TESTE ==================
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
pipeline.fit(X_train, y_train)

# Avaliação no conjunto de teste
y_pred = pipeline.predict(X_test)
y_prob = pipeline.predict_proba(X_test)[:,1]

print("\n📈 MÉTRICAS NO CONJUNTO DE TESTE:")
print(classification_report(y_test, y_pred))
print(f"AUC-ROC: {roc_auc_score(y_test, y_prob):.3f}")

# ================== ANÁLISE DE SUPERAJUSTE ==================
train_prob = pipeline.predict_proba(X_train)[:,1]
print("\n🔍 COMPARAÇÃO TREINO/TESTE:")
print(f"AUC Treino: {roc_auc_score(y_train, train_prob):.3f}")
print(f"AUC Teste: {roc_auc_score(y_test, y_prob):.3f}")
print("\nDiferença aceitável (<0.05)?" , 
      "✅ Sim" if abs(roc_auc_score(y_train, train_prob) - roc_auc_score(y_test, y_prob)) < 0.05 else "❌ Não")

# ================== FEATURE IMPORTANCE ==================
rf_model = pipeline.named_steps['randomforestclassifier']
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False)

print("\n🎯 TOP 10 VARIÁVEIS MAIS IMPORTANTES:")
print(importance.head(10).to_string())

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x='Importance', y='Feature', data=importance.head(10), palette='viridis')
plt.title('Feature Importance (Random Forest)')
plt.tight_layout()
plt.show()

# ================== RESPOSTA À PERGUNTA DE NEGÓCIO ==================
# Calcular probabilidades para combinações específicas de "companhia aérea + tipo de aeronave"
df['Probabilidade_BaixaPerformance'] = pipeline.predict_proba(X)[:,1]

# Criar tabela com as combinações e suas probabilidades médias
combinacoes = df.groupby(['Combinacao'])['Probabilidade_BaixaPerformance'].agg(['mean', 'count']).reset_index()
combinacoes.rename(columns={'mean': 'Probabilidade_Media', 'count': 'Frequencia'}, inplace=True)

# Filtrar combinações com maior risco (probabilidade alta)
combinacoes_risco = combinacoes[combinacoes['Probabilidade_Media'] > 0.5].sort_values(by='Probabilidade_Media', ascending=False)

print("\n🔍 COMBINAÇÕES COM MAIOR RISCO DE BAIXA PERFORMANCE:")
print(combinacoes_risco.to_string())

# Plot das combinações com maior risco
plt.figure(figsize=(12,6))
sns.barplot(data=combinacoes_risco.head(10), x='Probabilidade_Media', y='Combinacao', palette='Reds_r')
plt.title('Combinações com Maior Risco de Baixa Performance')
plt.xlabel('Probabilidade Média de Baixa Performance')
plt.ylabel('Combinação (Companhia Aérea + Tipo de Aeronave)')
plt.tight_layout()
plt.show()
# Out:
# 🔍 DISTRIBUIÇÃO DAS CLASSES:
# BaixaPerformance
# 0    0.739438
# 1    0.260562
# Name: proportion, dtype: float64
#
# 📊 VALIDAÇÃO CRUZADA (AUC-ROC):
# Média: 0.999 | Desvio Padrão: 0.000
# Intervalo (95%): [0.998, 0.999]
#
# 📈 MÉTRICAS NO CONJUNTO DE TESTE:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5928
#            1       0.98      0.98      0.98      2125
#
#     accuracy                           0.99      8053
#    macro avg       0.99      0.99      0.99      8053
# weighted avg       0.99      0.99      0.99      8053
#
# AUC-ROC: 0.999
#
# 🔍 COMPARAÇÃO TREINO/TESTE:
# AUC Treino: 1.000
# AUC Teste: 0.999
#
# Diferença aceitável (<0.05)? ✅ Sim
#
# 🎯 TOP 10 VARIÁVEIS MAIS IMPORTANTES:
#                                                 Feature  Importance
# 0                                   Total Landed Weight    0.837391
# 116                      Aircraft Body Type_Narrow Body    0.020024
# ...

# %% [markdown]
# **Interpretação**
#
#
# Com base nos resultados apresentados, podemos determinar que:
#
# *1. Combinações com 100% de probabilidade de baixa performance:*
#
# ATA Airlines + Wide Body
#
# Aeromexico + Wide Body
#
# Cargolux Airlines + Wide Body
#
# Federal Express + Narrow Body
#
# Swissport USA + Wide Body
#
# Entre outras listadas (total de 20 combinações)
#
# *2. Combinações com alto risco (acima de 90%):*
#
# Air Canada Jazz + Regional Jet (99.75%)
#
# Southern Air + Wide Body (99.59%)
#
# Astar Air Cargo + Narrow Body (99.50%)
#
# Finnair + Wide Body (99.50%)
#
# *3. Combinações com risco moderado (50-90%):*
#
# Air Canada + Wide Body (52.25%)
#
# Qatar Airways + Wide Body (52.81%)
#
# Qantas Airways + Wide Body (55.88%)
#
# *4. Fatores-chave que influenciam a baixa performance:*
#
# Peso Total Pousado (variável mais importante - 83.7% de importância)
#
# *Tipo de Aeronave:*
#
# Wide Body tem maior risco em combinações específicas
#
# Narrow Body apresenta risco em operações de carga
#
# *Companhia Aérea:*
#
# Operadoras de carga (Federal Express, Cargolux)
#
# Companhias regionais (Air Canada Jazz)

# %% [markdown]
# **E)Quais variáveis explicam melhor a escolha de aeronaves de corpo largo (wide body)?**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Suprimir warnings específicos
warnings.filterwarnings("ignore", category=FutureWarning)

# ================== FUNÇÕES AUXILIARES ==================

def preparar_variavel_numerica(df, feature, bins=5):
    """Agrupa variáveis numéricas em faixas usando quantis."""
    if pd.api.types.is_numeric_dtype(df[feature]):
        new_col = f"{feature}_bin"
        df[new_col] = pd.qcut(df[feature], q=bins, duplicates='drop').astype(str)
        return new_col
    return feature

def calcular_woe_iv(df, feature, target, woe_tables):
    """Calcula Weight of Evidence (WoE) e Information Value (IV)."""
    try:
        cross_tab = pd.crosstab(df[feature], df[target], margins=False)
        cross_tab = cross_tab.replace(0, 0.5)
        
        total_0 = cross_tab[0].sum()
        total_1 = cross_tab[1].sum()
        cross_tab['%_NaoWideBody'] = cross_tab[0] / total_0
        cross_tab['%_WideBody'] = cross_tab[1] / total_1
        
        cross_tab['WoE'] = np.log(cross_tab['%_NaoWideBody'] / cross_tab['%_WideBody'])
        cross_tab['IV'] = (cross_tab['%_NaoWideBody'] - cross_tab['%_WideBody']) * cross_tab['WoE']
        
        cross_tab['%_NaoWideBody'] = (cross_tab['%_NaoWideBody'] * 100).round(1).astype(str) + '%'
        cross_tab['%_WideBody'] = (cross_tab['%_WideBody'] * 100).round(1).astype(str) + '%'
        
        woe_tables[feature] = cross_tab.copy()
        return cross_tab['IV'].sum()
    
    except Exception as e:
        print(f"Erro ao processar {feature}: {str(e)}")
        return 0

def classificar_poder_preditivo(iv_value):
    if iv_value < 0.02: return 'Sem poder'
    elif iv_value < 0.1: return 'Fraco'
    elif iv_value < 0.3: return 'Moderado'
    elif iv_value < 0.5: return 'Forte'
    else: return 'Muito forte'

# ================== EXECUÇÃO PRINCIPAL ==================

# 1. Carregar e preparar os dados
df = pd.read_csv("Air_Traffic_Landings_Statistics.csv")

# Criando nossa variável alvo: 1 para Wide Body, 0 para outros tipos
df['WideBody'] = (df['Aircraft Body Type'] == 'Wide Body').astype(int)

# 2. Selecionar features que podem explicar a escolha de aeronaves wide body
features = [
    'Operating Airline',
    'Published Airline',
    'GEO Summary',
    'GEO Region',
    'Aircraft Manufacturer',
    'Total Landed Weight',
    'Landing Count'
]

# Pré-processamento para variáveis numéricas
for col in features:
    if pd.api.types.is_numeric_dtype(df[col]):
        q1, q3 = df[col].quantile(0.25), df[col].quantile(0.75)
        df[col] = np.clip(df[col], q1 - 1.5*(q3-q1), q3 + 1.5*(q3-q1))

# 3. Calcular WoE e IV
woe_results = {}
iv_values = {}

for feature in features:
    feature_name = preparar_variavel_numerica(df, feature)
    iv = calcular_woe_iv(df, feature_name, 'WideBody', woe_results)
    iv_values[feature] = iv

# 4. Criar tabela de resultados
iv_df = pd.DataFrame.from_dict(iv_values, orient='index', columns=['IV'])
iv_df['Poder Preditivo'] = iv_df['IV'].apply(classificar_poder_preditivo)
iv_df = iv_df.sort_values('IV', ascending=False)

# ================== VISUALIZAÇÃO ==================

plt.figure(figsize=(12,6))
ax = sns.barplot(
    x='IV', 
    y=iv_df.index, 
    data=iv_df, 
    hue=iv_df.index,
    palette='viridis', 
    legend=False
)

for p in ax.patches:
    ax.annotate(
        f"{p.get_width():.3f}", 
        (p.get_width() + 0.01, p.get_y() + p.get_height()/2),
        ha='left', 
        va='center'
    )

plt.title('Fatores que Influenciam a Escolha de Aeronaves de Corpo Largo', pad=20)
plt.xlabel('Information Value (IV)')
plt.ylabel('Variáveis')
plt.tight_layout()
plt.show()

# ================== RESULTADOS DETALHADOS ==================

print("\n🔍 TOP CATEGORIAS POR VARIÁVEL (IV ≥ 0.1)")

for feature in iv_df[iv_df['IV'] >= 0.1].index:
    feature_name = feature+'_bin' if feature+'_bin' in df.columns else feature
    
    if feature_name not in woe_results:
        continue
        
    print(f"\n► {feature} (IV = {iv_df.loc[feature,'IV']:.3f} - {iv_df.loc[feature,'Poder Preditivo']})")
    print("-"*60)
    
    woe_table = woe_results[feature_name].copy()
    cols = ['%_NaoWideBody', '%_WideBody', 'WoE', 'IV']
    woe_table = woe_table[[c for c in cols if c in woe_table.columns]]
    
    # Limitar a 15 registros e ordenar por WoE
    woe_table = woe_table.sort_values('WoE', ascending=True).head(15)
    
    if 'WoE' in woe_table.columns:
        woe_table['WoE'] = woe_table['WoE'].round(3)
    if 'IV' in woe_table.columns:
        woe_table['IV'] = woe_table['IV'].round(5)
    
    print(woe_table.to_string())
    
    if 'WoE' in woe_table.columns:
        print(f"\nInterpretação:")
        print(f"- Categoria com MAIOR tendência para Wide Body: {woe_table['WoE'].idxmin()}")
        print(f"- Categoria com MENOR tendência para Wide Body: {woe_table['WoE'].idxmax()}")
    
    print("="*85)

# Resumo executivo
print("\n⭐ RESUMO DAS VARIÁVEIS MAIS RELEVANTES PARA ESCOLHA DE AERONAVES WIDE BODY")
print(iv_df.to_string())

# Contagem total de aeronaves Wide Body vs demais tipos
total_wide = df['WideBody'].sum()
total = len(df)
percent_wide = (total_wide/total) * 100

print(f"\nEstatísticas gerais:")
print(f"- Total de pousos analisados: {total}")
print(f"- Pousos com aeronaves Wide Body: {total_wide} ({percent_wide:.1f}%)")
print(f"- Pousos com outros tipos de aeronaves: {total - total_wide} ({100-percent_wide:.1f}%)")
# Out:
# 🔍 TOP CATEGORIAS POR VARIÁVEL (IV ≥ 0.1)
#
# ► Operating Airline (IV = 8.074 - Muito forte)
# ------------------------------------------------------------
# WideBody                  %_NaoWideBody %_WideBody    WoE       IV
# Operating Airline
# Korean Air Lines                   0.0%       4.9% -7.236  0.35741
# China Airlines                     0.0%       3.2% -6.806  0.21855
# Cathay Pacific                     0.0%       3.1% -6.779  0.21188
# Asiana Airlines                    0.0%       3.1% -6.766  0.20886
# Lufthansa German Airlines          0.0%       3.1% -6.753  0.20584
# EVA Airways                        0.0%       3.0% -6.725  0.19921
# KLM Royal Dutch Airlines           0.0%       2.9% -6.698  0.19321
# Air France                         0.0%       2.9% -6.690  0.19141
# Philippine Airlines                0.0%       2.6% -6.593  0.17119
# British Airways                    0.0%       2.5% -6.547  0.16235
# ...

# %% [markdown]
# **Interpretação**
#
# *1. Operating Airline (IV = 8.074) – Muito Forte*
#
# Top 3 companhias com maior tendência a usar wide-body:
#
# Korean Air Lines (4.9%)
#
# China Airlines (3.2%)
#
# Cathay Pacific (3.1%)
#
# Interpretação: Companhias asiáticas dominam, indicando que rotas de longa distância (transoceânicas) são o principal fator.
#
# *2. Published Airline (IV = 7.308) – Muito Forte*
#
# Resultados quase idênticos ao Operating Airline, reforçando que a identidade da companhia aérea é crítica.
#
# *3. GEO Region (IV = 6.931) – Muito Forte*
#
# Top 3 regiões com maior uso de wide-body:
#
# Ásia (39.7%)
#
# Europa (24.0%)
#
# Austrália/Oceania (6.7%)
#
# Interpretação: Rotas intercontinentais (ex.: Ásia-Europa) exigem aeronaves de grande porte.
#
# *4. Aircraft Manufacturer (IV = 1.706) – Muito Forte*
#
# Top fabricantes de wide-body:
#
# Boeing (79.1%)
#
# Airbus (18.0%)
#
# Menor tendência: Bombardier e Embraer (0%).
#
# Interpretação: Wide-bodies são quase exclusivos de Boeing e Airbus, fabricantes especializados em aeronaves de longo alcance.
#
# *5. Landing Count (IV = 0.945) – Muito Forte*
#
# Faixa com maior uso de wide-body: 26–36 pousos (29.4%).
#
# Menor uso: 109–178 pousos (4.4%).
#
# Interpretação: Rotas de média frequência (não excessivamente saturadas) são as ideais para wide-bodies.
#
# *6. GEO Summary (IV = 0.736) – Muito Forte*
#
# Voos internacionais: 74% wide-body vs. domésticos: 26%.
#
# Interpretação: Voos entre países exigem maior capacidade e autonomia.
#
# *7. Total Landed Weight (IV = 0.336) – Forte*
#
# Faixa de peso mais associada a wide-body: 13–24 milhões de unidades (30.5%).
#
# Interpretação: Aeronaves mais pesadas (que transportam mais passageiros/carga) são tipicamente wide-bodies.

# %% [markdown]
# # 5 Conclusão 5W2H

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
import webbrowser
import os
import textwrap

def gerar_pdf_5w2h(data):
    # Configuração do documento PDF
    pdf_pages = PdfPages("Plano_Estrategico_AeroVision_5W2H.pdf")

    # Ajustes de layout
    fig, ax = plt.subplots(figsize=(14, 12))  # Aumentei a altura para caber melhor
    ax.axis('off')

    # Configurações de fonte
    font = FontProperties()
    font.set_size(10)
    font_bold = FontProperties()
    font_bold.set_size(11)
    font_bold.set_weight('bold')

    # Preparar os dados com quebras de linha
    wrapped_data = []
    max_lines = 1
    for elemento, descricao in zip(data['Elemento'], data['Descrição']):
        # Aplicar quebra de linha para descrições longas (limite de 70 caracteres por linha)
        wrapped_desc = textwrap.fill(descricao, width=70)
        lines = wrapped_desc.count('\n') + 1
        if lines > max_lines:
            max_lines = lines
        wrapped_data.append([elemento, wrapped_desc])

    # Criação da tabela
    table = ax.table(
        cellText=wrapped_data,
        colLabels=['Elemento', 'Descrição'],
        cellLoc='left',
        loc='center',
        colWidths=[0.15, 0.85]  # Ajuste das larguras das colunas
    )

    # Ajustes de formatação
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1.2, 1.2)  # Ajuste da escala

    # Estilização das células
    for (i, j), cell in table.get_celld().items():
        cell.set_edgecolor('#4682b4')
        cell.set_linewidth(0.7)
        if i == 0:
            cell.set_facecolor('#1e3d59')
            cell.set_text_props(color='white', fontproperties=font_bold)
        else:
            # Ajustar altura das linhas baseado no número de linhas do texto
            cell.set_height(0.15 * max_lines)
            cell.set_text_props(fontproperties=font)
            cell.PAD = 0.1  # Espaçamento interno

    # Finalização do layout
    plt.tight_layout(pad=3.0)
    pdf_pages.savefig(fig, bbox_inches='tight', dpi=300)
    pdf_pages.close()
    return "Plano_Estrategico_AeroVision_5W2H.pdf"

def gerenciar_pdf(pdf_path):
    print("\nOpções de Visualização:")
    resposta = input("[A]brir PDF | [B]aixar PDF | [V]isualizar Tabela: ").upper()

    if resposta == 'A':
        webbrowser.open(pdf_path)
    elif resposta == 'B':
        print(f"\nArquivo disponível em:\n{os.path.abspath(pdf_path)}")
    elif resposta == 'V':
        print("\n" + "=" * 100)
        print(pd.DataFrame(data).to_string(index=False))
        print("=" * 100)
    else:
        print("Opção inválida. Por favor, tente novamente.")

# Dados do plano 5W2H para AeroVision
data = {
    "Elemento": [
        "What",
        "Why",
        "Where",
        "When",
        "Who",
        "How",
        "How Much"
    ],
    "Descrição": [
        "Análise de dados de pousos no Aeroporto de San Francisco (SFO) para gerar insights sobre operação de aeronaves, com foco em eficiência, performance e oportunidades estratégicas para a AeroVision",
        "Melhorar a alocação da frota, reduzir custos operacionais, identificar padrões de uso de aeronaves e apoiar decisões estratégicas com base em dados históricos",
        "Aplicação interna na AeroVision, com base em dados públicos do aeroporto SFO. A análise será apresentada às áreas de Planejamento Operacional, Engenharia e Estratégia",
        "Início imediato da análise. Entregas em até 3 semanas",
        "Equipe de Dados e Estratégia da AeroVision (Product Owner: área de Planejamento Operacional; Dev Team: analistas de dados; Scrum Master: gerente de projetos)",
        "Utilização de técnicas de EDA (Análise Exploratória de Dados), modelagem estatística e visualização para responder às perguntas de negócio previamente definidas",
        "Projeto de baixo custo operacional (uso de dados públicos e ferramentas de análise como Python/Pandas/Matplotlib/Seaborn), com alto potencial de retorno estratégico"
    ]
}

if __name__ == "__main__":
    df = pd.DataFrame(data)
    arquivo_pdf = gerar_pdf_5w2h(df)
    gerenciar_pdf(arquivo_pdf)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16360\1776907346.py:63: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(pad=3.0)
# Opções de Visualização:
# [A]brir PDF | [B]aixar PDF | [V]isualizar Tabela:  a

# %% [markdown]
# ## 5.1 Scrum do Projeto

# %%
def gerar_pdf_scrum():
    # Nome do arquivo PDF
    pdf_filename = "Scrum_Projeto_Analise_Aeronaves.pdf"
    pdf_pages = PdfPages(pdf_filename)

    # Função auxiliar para criar tabelas
    def criar_tabela(ax, data, titulo):
        ax.axis('off')
        ax.set_title(titulo, fontsize=14, fontweight='bold', pad=10)

        df = pd.DataFrame(data)
        table = ax.table(
            cellText=df.values,
            colLabels=list(df.columns),
            cellLoc='left',
            loc='center',
            colWidths=[0.2, 0.8]
        )

        table.auto_set_font_size(False)
        table.set_fontsize(10)
        table.scale(1.1, 1.5)

        for (i, j), cell in table.get_celld().items():
            cell.set_edgecolor('#3a7ca5')
            if i == 0:
                cell.set_facecolor('#2f6690')
                cell.set_text_props(color='white', weight='bold')
            else:
                cell.set_height(0.2)

    # Criar figura com 4 seções
    fig, axs = plt.subplots(4, 1, figsize=(14, 18))

    # 1. Visão do Produto
    data_visao = {
        "Item": ["Objetivo", "Valor Esperado"],
        "Descrição": [
            "Realizar análise de dados de operações de aeronaves para identificar padrões e oportunidades",
            "Fornecer insights estratégicos para otimização de frota e parcerias com fabricantes"
        ]
    }
    criar_tabela(axs[0], data_visao, "Visão do Produto")

    # 2. Backlog do Produto (Sprints)
    data_sprints = {
        "Sprint": ["Sprint 1 (Semana 1)", 
                  "Sprint 2 (Semana 2)", 
                  "Sprint 3 (Semana 3)"],
        "Tarefas": [
            "Importação e limpeza dos dados\nAnálise descritiva inicial\nEstruturação dos KPIs",
            "Análise estatística para responder perguntas de negócio\nDesenvolvimento de modelos\nGeração de visualizações",
            "Construção de dashboard/apresentação\nRecomendações de ações estratégicas\nPreparação de relatórios finais"
        ]
    }
    criar_tabela(axs[1], data_sprints, "Backlog do Produto - Sprints")

    # 3. Equipe Scrum
    data_equipe = {
        "Função": ["Product Owner", 
                  "Scrum Master", 
                  "Time de Desenvolvimento"],
        "Responsabilidades": [
            "Definir prioridades e garantir que a análise atenda às necessidades do negócio",
            "Facilitar o processo ágil e garantir o cumprimento do cronograma",
            "Analistas de dados, estatísticos e especialistas em aviação"
        ]
    }
    criar_tabela(axs[2], data_equipe, "Equipe Scrum")

    # 4. Métricas de Sucesso
    data_metricas = {
        "Métrica": ["Qualidade dos dados", 
                   "Relevância dos insights", 
                   "Clareza das visualizações", 
                   "Aplicabilidade das recomendações"],
        "Meta": [
            "Dados completos e limpos",
            "Responder a todas as perguntas de negócio",
            "Visualizações compreensíveis para decisores",
            "Recomendações acionáveis pela equipe de operações"
        ]
    }
    criar_tabela(axs[3], data_metricas, "Métricas de Sucesso")

    # Ajustar layout e salvar PDF
    plt.tight_layout(pad=3.0)
    pdf_pages.savefig(fig, bbox_inches='tight')
    pdf_pages.close()

    print(f"PDF '{pdf_filename}' gerado com sucesso!")
    return pdf_filename

def visualizar_pdf(pdf_path):
    webbrowser.open(pdf_path)

if __name__ == "__main__":
    pdf_file = gerar_pdf_scrum()
    visualizar_pdf(pdf_file)
# Out:
# PDF 'Scrum_Projeto_Analise_Aeronaves.pdf' gerado com sucesso!

# %% [markdown]
# ## 5.2 Resumo dos Ganhos Financeiros

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import textwrap
import matplotlib.patches as patches
import os
import base64
import fitz  # PyMuPDF

# Configurações globais de estilo
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['axes.unicode_minus'] = False

def converter_pdf_para_imagens(pdf_path):
    """Converte cada página do PDF para imagem PNG"""
    doc = fitz.open(pdf_path)
    imagens = []
    
    for page in doc:
        pix = page.get_pixmap(dpi=150)
        img_bytes = pix.tobytes("png")
        img_base64 = base64.b64encode(img_bytes).decode('utf-8')
        imagens.append(img_base64)
    
    return imagens

def visualizar_pdf_no_jupyter(pdf_path):
    # Converter cada página do PDF para imagem
    imagens = converter_pdf_para_imagens(pdf_path)
    
    # HTML para exibir todas as páginas como imagens, uma após a outra
    html_content = """
    <div style="display: flex; flex-direction: column; align-items: center; gap: 30px;">
    """
    
    for img_base64 in imagens:
        html_content += f"""
        <div style="width: 100%; display: flex; justify-content: center;">
            <img src="data:image/png;base64,{img_base64}" style="max-width: 100%; height: auto; border: 1px solid #ddd; box-shadow: 0 2px 5px rgba(0,0,0,0.1);">
        </div>
        """
    
    html_content += f"""
    </div>
    
    <div style="margin: 20px 0; padding: 15px; background: #f5f8fa; border-radius: 5px; text-align: center;">
        <strong style="color: #1e3d59;">Opções:</strong>
        <a href="{pdf_path}" download style="margin-left: 15px; text-decoration: none; color: #2f6690; font-weight: bold; padding: 5px 10px; border: 1px solid #2f6690; border-radius: 3px;">⬇️ Baixar Relatório Completo</a>
        <a href="{pdf_path}" target="_blank" style="margin-left: 15px; text-decoration: none; color: #2f6690; font-weight: bold; padding: 5px 10px; border: 1px solid #2f6690; border-radius: 3px;">🔗 Abrir em Nova Aba</a>
    </div>
    """
    
    display(HTML(html_content))

if __name__ == "__main__":
    # Gera o relatório completo (funções anteriores permanecem iguais)
    pdf_path = gerar_relatorio_completo()
    
    # Mostra no Jupyter
    try:
        from IPython import get_ipython
        if get_ipython() is not None:
            visualizar_pdf_no_jupyter(pdf_path)
    except:
        print(f"Relatório gerado com sucesso: {os.path.abspath(pdf_path)}")
# Out:
#     <div style="display: flex; flex-direction: column; align-items: center; gap: 30px;">
#
#         <div style="width: 100%; display: flex; justify-content: center;">
#             <img src="data:image/png;base64,..." style="max-width: 100%; height: auto; border: 1px solid #ddd; box-shadow: 0 2px 5px rgba(0,0,0,0.1);">
#         </div>
#
#         <div style="width: 100%; display: flex; justify-content: center;">
#             <img src="data:image/png;base64,..." style="max-width: 100%; height: auto; border: 1px solid #ddd; box-shadow: 0 2px 5px rgba(0,0,0,0.1);">
#         </div>
#
#         <div style="width: 100%; display: flex; justify-content: center;">
#             <img src="data:image/png;base64,..." style="max-width: 100%; height: auto; border: 1px solid #ddd; box-shadow: 0 2px 5px rgba(0,0,0,0.1);">
#         </div>
#
#     </div>
#
#     <div style="margin: 20px 0; padding: 15px; background: #f5f8fa; border-radius: 5px; text-align: center;">
# ...
